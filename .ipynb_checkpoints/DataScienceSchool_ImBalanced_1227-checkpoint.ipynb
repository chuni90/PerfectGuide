# %% [markdown]
# # 비대칭 데이터 문제

# %% [markdown]
# 데이터 클래스 비율이 너무 차이가 나면(highly-imbalanced data) 단순히 우세한 클래스를 택하는 모형의 정확도가 높아지므로 모형의 성능판별이 어려워진다. 즉, 정확도(accuracy)가 높아도 데이터 갯수가 적은 클래스의 재현율(recall-rate)이 급격히 작아지는 현상이 발생할 수 있다.
#
# 이렇게 각 클래스에 속한 데이터의 갯수의 차이에 의해 발생하는 문제들을 비대칭 데이터 문제(imbalanced data problem)이라고 한다.

# %%
from sklearn.datasets import *
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import scipy as sp
import numpy as np
import pandas as pd

# %%
def classification_result(n0, n1, title=""):
    rv1 = sp.stats.multivariate_normal([-1, 0], [[1, 0], [0, 1]])
    rv2 = sp.stats.multivariate_normal([+1, 0], [[1, 0], [0, 1]])
    X0 = rv1.rvs(n0, random_state=0)
    X1 = rv2.rvs(n1, random_state=0)
    X = np.vstack([X0, X1])
    y = np.hstack([np.zeros(n0), np.ones(n1)])

    x1min = -4; x1max = 4
    x2min = -2; x2max = 2
    xx1 = np.linspace(x1min, x1max, 1000)
    xx2 = np.linspace(x2min, x2max, 1000)
    X1, X2 = np.meshgrid(xx1, xx2)

    plt.contour(X1, X2, rv1.pdf(np.dstack([X1, X2])), levels=[0.05], linestyles="dashed")
    plt.contour(X1, X2, rv2.pdf(np.dstack([X1, X2])), levels=[0.05], linestyles="dashed")

    model = SVC(kernel="linear", C=1e4, random_state=0).fit(X, y)
    Y = np.reshape(model.predict(np.array([X1.ravel(), X2.ravel()]).T), X1.shape)
    plt.scatter(X[y == 0, 0], X[y == 0, 1], marker='x', label="0 class")
    plt.scatter(X[y == 1, 0], X[y == 1, 1], marker='o', label="1 class")
    plt.contour(X1, X2, Y, colors='k', levels=[0.5])
    y_pred = model.predict(X)
    plt.xlim(-4, 4)
    plt.ylim(-3, 3)
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(title)
    
    return model, X, y, y_pred

# %%
plt.subplot(121)
model1, X1, y1, y_pred1 = classification_result(200, 200, "Balacned Data (5:5)")
plt.subplot(122)
model2, X2, y2, y_pred2 = classification_result(200, 20, "ImBalacned Data (9:1)")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y1, y_pred1))
print(classification_report(y2, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.83      0.84       200
#          1.0       0.84      0.86      0.85       200
#
#     accuracy                           0.85       400
#    macro avg       0.85      0.85      0.85       400
# weighted avg       0.85      0.85      0.85       400
#
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97       200
#          1.0       0.75      0.60      0.67        20
#
#     accuracy                           0.95       220
#    macro avg       0.86      0.79      0.82       220
# weighted avg       0.94      0.95      0.94       220

# %%
def get_eval(y_test, pred_) :
#     cms, accs, pres, recalls, f1s, rocs = [], 0., 0., 0., 0., 0.
    from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_auc_score 
    
    cm = confusion_matrix(y_test, pred_)
    acc = np.round(accuracy_score(y_test, pred_),3)
    pre = np.round(precision_score(y_test, pred_),3)
    recall = np.round(recall_score(y_test, pred_),3)
    f1 = np.round(f1_score(y_test, pred_),3)
    roc_auc = np.round(roc_auc_score(y_test, pred_),3)
    
#     cms.extend(cm)
#     accs.extend(acc)
#     pres.extend(pre)
#     recalls.extend(recall)
#     f1s.extend(f1)
#     rocs.extend(roc_auc)

    return cm, acc, pre, recall, f1, roc_auc

def make_series(y_test, pred_, index_name) :
    cm, acc, pre, recall, f1, roc_auc = get_eval(y_test, pred_)
    scores = pd.Series({'c_m':cm, 'acc': acc, 'precision':pre, 'recall':recall, 'f1':f1, 'roc_auc':roc_auc},
                             name=index_name)
    return scores

a1 = make_series(y2, y_pred2, 'Imbalanced')
a1
# Out:
# c_m          [[196, 4], [8, 12]]
# acc                        0.945
# precision                   0.75
# recall                       0.6
# f1                         0.667
# roc_auc                     0.79
# Name: Imbalanced, dtype: object

# %%
from sklearn.metrics import roc_curve, confusion_matrix

fpr1, tpr1, thresholds1 = roc_curve(y1, model1.decision_function(X1))
fpr2, tpr2, thresholds2 = roc_curve(y2, model2.decision_function(X2))

c1 = confusion_matrix(y1, y_pred1, labels=[1, 0])
c2 = confusion_matrix(y2, y_pred2, labels=[1, 0])
r1 = c1[0, 0] / (c1[0, 0] + c1[0, 1])
r2 = c2[0, 0] / (c2[0, 0] + c2[0, 1])
f1 = c1[1, 0] / (c1[1, 0] + c1[1, 1])
f2 = c2[1, 0] / (c2[1, 0] + c2[1, 1])

plt.plot(fpr1, tpr1, ':', label="Balacned")
plt.plot(fpr2, tpr2, '-', label="ImBalacned")
plt.plot([f1], [r1], 'ro')
plt.plot([f2], [r2], 'ro')
plt.legend()
plt.xlabel('Fall-Out')
plt.ylabel('Recall')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ## 해결 방법

# %% [markdown]
# 비대칭 데이터는 다수 클래스 데이터에서 일부만 사용하는 **언더 샘플링**이나 소수 클래스 데이터를 증가시키는 **오버 샘플링**을 사용하여 데이터 비율을 맞추면 정밀도(precision)가 향상된다.
#
# * 오버샘플링(Over-Sampling)
# * 언더샘플링(Under-Sampling)
# * 복합샘플링(Combining Over-and Under-Sampling)

# %% [markdown]
# ## imbalanced-learn 패키지

# %% [markdown]
# imbalanced data 문제를 해결하기 위한 다양한 샘플링 방법을 구현한 파이썬 패키지
#
#
# ```
# pip install -U imbalanced-learn
# ```

# %%
import imblearn
imblearn.__version__
# Out:
# '0.6.1'

# %% [markdown]
# ## 언더 샘플링

# %% [markdown]
# * `RandomUnderSampler`: random under-sampling method
# * `TomekLinks`: Tomek’s link method
# * `CondensedNearestNeighbour`: condensed nearest neighbour method
# * `OneSidedSelection`: under-sampling based on one-sided selection method
# * `EditedNearestNeighbours`: edited nearest neighbour method
# * `NeighbourhoodCleaningRule`: neighbourhood cleaning rule

# %%
from imblearn.under_sampling import *

n0 = 200; n1 = 20
rv1 = sp.stats.multivariate_normal([-1, 0], [[1, 0], [0, 1]])
rv2 = sp.stats.multivariate_normal([+1, 0], [[1, 0], [0, 1]])
X0 = rv1.rvs(n0, random_state=0)
X1 = rv2.rvs(n1, random_state=0)
X_imb = np.vstack([X0, X1])
y_imb = np.hstack([np.zeros(n0), np.ones(n1)])

x1min = -4; x1max = 4
x2min = -2; x2max = 2
xx1 = np.linspace(x1min, x1max, 1000)
xx2 = np.linspace(x2min, x2max, 1000)
X1, X2 = np.meshgrid(xx1, xx2)

# %%
def classification_result2(X, y, title=""):
    
    # class 0 & 1 개수 차이 확인
    print("Y==0 : {0} || Y==1 : {1}".format( y[y==0].shape[0], y[y==1].shape[0]))
    
    plt.contour(X1, X2, rv1.pdf(np.dstack([X1, X2])), levels=[0.05], linestyles="dashed")
    plt.contour(X1, X2, rv2.pdf(np.dstack([X1, X2])), levels=[0.05], linestyles="dashed")
    model = SVC(kernel="linear", C=1e4, random_state=0).fit(X, y)
    Y = np.reshape(model.predict(np.array([X1.ravel(), X2.ravel()]).T), X1.shape)
    plt.scatter(X[y == 0, 0], X[y == 0, 1], marker='x', label="0 클래스")
    plt.scatter(X[y == 1, 0], X[y == 1, 1], marker='o', label="1 클래스")
    plt.contour(X1, X2, Y, colors='k', levels=[0.5])
    y_pred = model.predict(X)
    plt.xlim(-4, 4)
    plt.ylim(-3, 3)
    plt.xlabel("x1")
    plt.ylabel("x2")
    plt.title(title)
    return model

# %% [markdown]
# ## Ramdom Under-Sampler

# %% [markdown]
# * 무작위로 데이터를 없애는 단순 샘플링

# %%
X_samp, y_samp = RandomUnderSampler(random_state=0).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 20 || Y==1 : 20

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.92      0.95       200
#          1.0       0.51      0.90      0.65        20
#
#     accuracy                           0.91       220
#    macro avg       0.75      0.91      0.80       220
# weighted avg       0.95      0.91      0.92       220

# %%
# Seris로 결과 생성
a2 = make_series(y_imb, model_samp.predict(X_imb),'Ramdom Under-Sampler')
a2
# Out:
# c_m          [[183, 17], [2, 18]]
# acc                         0.914
# precision                   0.514
# recall                        0.9
# f1                          0.655
# roc_auc                     0.908
# Name: Ramdom Under-Sampler, dtype: object

# %% [markdown]
# ## Tomek’s link method

# %% [markdown]
# 토멕링크(Tomek’s link)란 서로 다른 클래스에 속하는 한 쌍의 데이터 $(x_{+}, x_{-})$로 서로에게 더 가까운 다른 데이터가 존재하지 않는 것이다. 즉 클래스가 다른 두 데이터가 아주 가까이 붙어있으면 토멕링크가 된다. 토멕링크 방법은 이러한 토멕링크를 찾은 다음 그 중에서 다수 클래스에 속하는 데이터를 제외하는  방법으로 경계선을 다수 클래스쪽으로 밀어붙이는 효과가 있다.

# %% [markdown]
# <img src="https://datascienceschool.net/upfiles/40e445c6271b438194813ebf54431d17.png" width="100%"/>

# %%
X_samp, y_samp = TomekLinks().fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 192 || Y==1 : 20

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97       200
#          1.0       0.70      0.70      0.70        20
#
#     accuracy                           0.95       220
#    macro avg       0.83      0.83      0.83       220
# weighted avg       0.95      0.95      0.95       220

# %%
# Seris로 결과 생성
a3 = make_series(y_imb, model_samp.predict(X_imb),'Tomek’s link method')
a3
# Out:
# c_m          [[194, 6], [6, 14]]
# acc                        0.945
# precision                    0.7
# recall                       0.7
# f1                           0.7
# roc_auc                    0.835
# Name: Tomek’s link method, dtype: object

# %% [markdown]
# ## Condensed Nearest Neighbour

# %% [markdown]
# CNN(Condensed Nearest Neighbour) 방법은 1-NN 모형으로 분류되지 않는 데이터만 남기는 방법이다. 선텍된 데이터 집합을 $S$라고 하자.
#
# 1. 소수 클래스 데이터를 모두 $S$에 포함시킨다.
# 2. 다수 데이터 중에서 하나를 골라서 가장 가까운 데이터가 다수 클래스이면 포함시키지 않고 아니면 $S$에 포함시킨다.
# 3. 더이상 선택되는 데이터가 없을 때까지 2를 반복한다.
#
# 이 방법을 사용하면 기존에 선택된 데이터와 가까이 있으면서 같은 클래스인 데이터는 선택되지 않기 때문에 다수 데이터의 경우 선택되는 비율이 적어진다.

# %%
X_samp, y_samp = CondensedNearestNeighbour(random_state=0).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 32 || Y==1 : 20

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97       200
#          1.0       0.75      0.60      0.67        20
#
#     accuracy                           0.95       220
#    macro avg       0.86      0.79      0.82       220
# weighted avg       0.94      0.95      0.94       220

# %%
a4 = make_series(y_imb, model_samp.predict(X_imb),'Condensed Nearest Neighbour')
a4
# Out:
# c_m          [[196, 4], [8, 12]]
# acc                        0.945
# precision                   0.75
# recall                       0.6
# f1                         0.667
# roc_auc                     0.79
# Name: Condensed Nearest Neighbour, dtype: object

# %% [markdown]
# ## One Sided Selection

# %% [markdown]
# One Sided Selection은 토맥링크 방법과 Condensed Nearest Neighbour 방법을 섞은 것이다. 토맥링크 중 다수 클래스를 제외하고 나머지 데이터 중에서도 서로 붙어있는 다수 클래스 데이터는 1-NN 방법으로 제외한다.

# %%
X_samp, y_samp = OneSidedSelection(random_state=0).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 115 || Y==1 : 20

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97       200
#          1.0       0.70      0.70      0.70        20
#
#     accuracy                           0.95       220
#    macro avg       0.83      0.83      0.83       220
# weighted avg       0.95      0.95      0.95       220

# %%
a5 = make_series(y_imb, model_samp.predict(X_imb),'One Sided Selection')
a5
# Out:
# c_m          [[194, 6], [6, 14]]
# acc                        0.945
# precision                    0.7
# recall                       0.7
# f1                           0.7
# roc_auc                    0.835
# Name: One Sided Selection, dtype: object

# %% [markdown]
# ## Edited Nearest Neighbours

# %% [markdown]
# ENN(Edited Nearest Neighbours) 방법은 다수 클래스 데이터 중 가장 가까운 k(`n_neighbors`)개의 데이터가 모두(`kind_sel="all"`) 또는 다수(`kind_sel="mode"`) 다수 클래스가 아니면 삭제하는 방법이다. 소수 클래스 주변의 다수 클래스 데이터는 사라진다.

# %%
X_samp, y_samp = EditedNearestNeighbours(kind_sel="all", n_neighbors=5).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 175 || Y==1 : 20

# %%
X_samp, y_samp = EditedNearestNeighbours(kind_sel="all", n_neighbors=10).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 166 || Y==1 : 20

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.93      0.96       200
#          1.0       0.56      0.95      0.70        20
#
#     accuracy                           0.93       220
#    macro avg       0.78      0.94      0.83       220
# weighted avg       0.96      0.93      0.94       220

# %%
a6 = make_series(y_imb, model_samp.predict(X_imb),'ENN')
a6
# Out:
# c_m          [[185, 15], [1, 19]]
# acc                         0.927
# precision                   0.559
# recall                       0.95
# f1                          0.704
# roc_auc                     0.938
# Name: ENN, dtype: object

# %% [markdown]
# ## Neighbourhood Cleaning Rule

# %% [markdown]
# Neighbourhood Cleaning Rule 방법은 CNN(Condensed Nearest Neighbour) 방법과 ENN(Edited Nearest Neighbours) 방법을 섞은 것이다.

# %%
X_samp, y_samp = NeighbourhoodCleaningRule(kind_sel="all", n_neighbors=5).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 174 || Y==1 : 20

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.93      0.96       200
#          1.0       0.56      0.95      0.70        20
#
#     accuracy                           0.93       220
#    macro avg       0.78      0.94      0.83       220
# weighted avg       0.96      0.93      0.94       220

# %%
a7 = make_series(y_imb, model_samp.predict(X_imb),'Neighbourhood Cleaning Rule')
a7
# Out:
# c_m          [[185, 15], [1, 19]]
# acc                         0.927
# precision                   0.559
# recall                       0.95
# f1                          0.704
# roc_auc                     0.938
# Name: Neighbourhood Cleaning Rule, dtype: object

# %% [markdown]
# ## 오버 샘플링

# %% [markdown]
# * `RandomOverSampler`: random sampler
# * `ADASYN`: Adaptive Synthetic Sampling Approach for Imbalanced Learning
# * `SMOTE`: Synthetic Minority Over-sampling Technique

# %%
from imblearn.over_sampling import *

# %% [markdown]
# ## RandomOverSampler

# %% [markdown]
# Random Over Sampling은 소수 클래스의 데이터를 반복해서 넣는 것(replacement)이다. 가중치를 증가시키는 것과 비슷하다.

# %%
X_samp, y_samp = RandomOverSampler(random_state=0).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)

# 동일한 값이 여러개 생기는 바람에 그래프가 겹쳐져서, 오버샘플링 되지 않은 것처럼 보임
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 200 || Y==1 : 200

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.91      0.95       200
#          1.0       0.51      0.95      0.67        20
#
#     accuracy                           0.91       220
#    macro avg       0.75      0.93      0.81       220
# weighted avg       0.95      0.91      0.92       220

# %%
a8 = make_series(y_imb, model_samp.predict(X_imb),'RandomOverSampler')
a8
# Out:
# c_m          [[182, 18], [1, 19]]
# acc                         0.914
# precision                   0.514
# recall                       0.95
# f1                          0.667
# roc_auc                      0.93
# Name: RandomOverSampler, dtype: object

# %% [markdown]
# ## ADASYN

# %% [markdown]
# ADASYN(Adaptive Synthetic Sampling) 방법은 소수 클래스 데이터와 그 데이터에서 가장 가까운 k개의 소수 클래스 데이터 중 무작위로 선택된 데이터 사이의 직선상에 가상의 소수 클래스 데이터를 만드는 방법이다.

# %%
X_samp, y_samp = ADASYN(random_state=0).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 200 || Y==1 : 204

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.90      0.94       200
#          1.0       0.47      0.95      0.63        20
#
#     accuracy                           0.90       220
#    macro avg       0.73      0.92      0.79       220
# weighted avg       0.95      0.90      0.91       220

# %%
a9 = make_series(y_imb, model_samp.predict(X_imb),'ADASYN')
a9
# Out:
# c_m          [[179, 21], [1, 19]]
# acc                           0.9
# precision                   0.475
# recall                       0.95
# f1                          0.633
# roc_auc                     0.922
# Name: ADASYN, dtype: object

# %% [markdown]
# ## SMOTE

# %% [markdown]
# SMOTE(Synthetic Minority Over-sampling Technique) 방법도 ADASYN 방법처럼 데이터를 생성하지만 생성된 데이터를 무조건 소수 클래스라고 하지 않고 분류 모형에 따라 분류한다.

# %% [markdown]
# <img src="https://datascienceschool.net/upfiles/e072f6e270884b2887051f2c10f433e7.png" width="100%"/>

# %%
X_samp, y_samp = SMOTE(random_state=4).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 200 || Y==1 : 200

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.91      0.95       200
#          1.0       0.50      0.90      0.64        20
#
#     accuracy                           0.91       220
#    macro avg       0.74      0.91      0.80       220
# weighted avg       0.94      0.91      0.92       220

# %%
a10 = make_series(y_imb, model_samp.predict(X_imb),'SMOTE')
a10
# Out:
# c_m          [[182, 18], [2, 18]]
# acc                         0.909
# precision                     0.5
# recall                        0.9
# f1                          0.643
# roc_auc                     0.905
# Name: SMOTE, dtype: object

# %% [markdown]
# ## 복합 샘플링

# %% [markdown]
# * `SMOTEENN`: SMOTE + ENN
# * `SMOTETomek`: SMOTE + Tomek

# %%
from imblearn.combine import *

# %% [markdown]
# ## SMOTE+ENN

# %% [markdown]
# SMOTE+ENN 방법은 SMOTE(Synthetic Minority Over-sampling Technique) 방법과 ENN(Edited Nearest Neighbours) 방법을 섞은 것이다.

# %%
X_samp, y_samp = SMOTEENN(random_state=0).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 161 || Y==1 : 174

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.92      0.96       200
#          1.0       0.54      0.95      0.69        20
#
#     accuracy                           0.92       220
#    macro avg       0.77      0.94      0.82       220
# weighted avg       0.95      0.92      0.93       220

# %%
a11 = make_series(y_imb, model_samp.predict(X_imb),'SMOTE+ENN')
a11
# Out:
# c_m          [[184, 16], [1, 19]]
# acc                         0.923
# precision                   0.543
# recall                       0.95
# f1                          0.691
# roc_auc                     0.935
# Name: SMOTE+ENN, dtype: object

# %% [markdown]
# ## SMOTE+Tomek

# %% [markdown]
# SMOTE+Tomek 방법은 SMOTE(Synthetic Minority Over-sampling Technique) 방법과 토멕링크 방법을 섞은 것이다.

# %%
X_samp, y_samp = SMOTETomek(random_state=4).fit_sample(X_imb, y_imb)
plt.figure(figsize=(10,4))
plt.subplot(121)
classification_result2(X_imb, y_imb)
plt.subplot(122)
model_samp = classification_result2(X_samp, y_samp)
# Out:
# Y==0 : 200 || Y==1 : 20
# Y==0 : 190 || Y==1 : 190

# %%
print(classification_report(y_imb, model_samp.predict(X_imb)))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.92      0.95       200
#          1.0       0.51      0.90      0.65        20
#
#     accuracy                           0.91       220
#    macro avg       0.75      0.91      0.80       220
# weighted avg       0.95      0.91      0.92       220

# %%
a12 = make_series(y_imb, model_samp.predict(X_imb),'SMOTE+Tomek')
a12
# Out:
# c_m          [[183, 17], [2, 18]]
# acc                         0.914
# precision                   0.514
# recall                        0.9
# f1                          0.655
# roc_auc                     0.908
# Name: SMOTE+Tomek, dtype: object

# %%
imp_list = []
for i in range(1,13) :
    imp_list.append('a' + str(i))
print(imp_list)
# Out:
# ['a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8', 'a9', 'a10', 'a11', 'a12']

# %%
# 각 샘플링별 score를 df로 만들기

df = pd.DataFrame(a1).transpose()
s_list = [a2, a3, a4, a5, a6, a7, a8, a9, a10, a11, a12]

# 반복 추가
for i in range(len(s_list)) :
    imp = pd.DataFrame(s_list[i]).transpose()
    df = df.append(imp)

# 언더샘플링인지 오버샘플링인지 추가
method = ['-','under','under','under','under','under','under','over','over','over','over','over']
df.insert(0, 'method', method)
df
# Out:
#                             method                   c_m    acc precision  \
# Imbalanced                       -   [[196, 4], [8, 12]]  0.945      0.75
# Ramdom Under-Sampler         under  [[183, 17], [2, 18]]  0.914     0.514
# Tomek’s link method          under   [[194, 6], [6, 14]]  0.945       0.7
# Condensed Nearest Neighbour  under   [[196, 4], [8, 12]]  0.945      0.75
# One Sided Selection          under   [[194, 6], [6, 14]]  0.945       0.7
# ENN                          under  [[185, 15], [1, 19]]  0.927     0.559
# Neighbourhood Cleaning Rule  under  [[185, 15], [1, 19]]  0.927     0.559
# RandomOverSampler             over  [[182, 18], [1, 19]]  0.914     0.514
# ADASYN                        over  [[179, 21], [1, 19]]    0.9     0.475
# SMOTE                         over  [[182, 18], [2, 18]]  0.909       0.5
# SMOTE+ENN                     over  [[184, 16], [1, 19]]  0.923     0.543
# SMOTE+Tomek                   over  [[183, 17], [2, 18]]  0.914     0.514
#
#                             recall     f1 roc_auc
# Imbalanced                     0.6  0.667    0.79
# Ramdom Under-Sampler           0.9  0.655   0.908
# Tomek’s link method            0.7    0.7   0.835
# Condensed Nearest Neighbour    0.6  0.667    0.79
# One Sided Selection            0.7    0.7   0.835
# ENN                           0.95  0.704   0.938
# Neighbourhood Cleaning Rule   0.95  0.704   0.938
# RandomOverSampler             0.95  0.667    0.93
# ADASYN                        0.95  0.633   0.922
# SMOTE                          0.9  0.643   0.905
# SMOTE+ENN                     0.95  0.691   0.935
# SMOTE+Tomek                    0.9  0.655   0.908

# %%
# 랭크를 매겨보자
df['acc_rank'] = df['acc'].rank(method='min', ascending=False)
df['precision_rank'] = df['precision'].rank(method='min', ascending=False)
df['recall_rank'] = df['recall'].rank(method='min', ascending=False)
df['f1_rank'] = df['f1'].rank(method='min', ascending=False)
df['roc_rank'] = df['roc_auc'].rank(method='min', ascending=False)
df['rank_sum'] = df['acc_rank'] + df['precision_rank'] + df['recall_rank'] + df['f1_rank'] + df['roc_rank']

# %%
df.sort_values('acc', ascending=False)

# accuracy 기준으로 아무 샘플링을 하지 않은 Imbalanced, Tomek, Condensed Nearest Neighborh, One Sided Selection이 공동 1위
# 다음으로 ENN, NCN, SMOTE+ENN 순으로 나타남
# Out:
#                             method                   c_m    acc precision  \
# Imbalanced                       -   [[196, 4], [8, 12]]  0.945      0.75
# Tomek’s link method          under   [[194, 6], [6, 14]]  0.945       0.7
# Condensed Nearest Neighbour  under   [[196, 4], [8, 12]]  0.945      0.75
# One Sided Selection          under   [[194, 6], [6, 14]]  0.945       0.7
# ENN                          under  [[185, 15], [1, 19]]  0.927     0.559
# Neighbourhood Cleaning Rule  under  [[185, 15], [1, 19]]  0.927     0.559
# SMOTE+ENN                     over  [[184, 16], [1, 19]]  0.923     0.543
# Ramdom Under-Sampler         under  [[183, 17], [2, 18]]  0.914     0.514
# RandomOverSampler             over  [[182, 18], [1, 19]]  0.914     0.514
# SMOTE+Tomek                   over  [[183, 17], [2, 18]]  0.914     0.514
# SMOTE                         over  [[182, 18], [2, 18]]  0.909       0.5
# ADASYN                        over  [[179, 21], [1, 19]]    0.9     0.475
#
#                             recall     f1 roc_auc  acc_rank  precision_rank  \
# Imbalanced                     0.6  0.667    0.79       1.0             1.0
# Tomek’s link method            0.7    0.7   0.835       1.0             3.0
# Condensed Nearest Neighbour    0.6  0.667    0.79       1.0             1.0
# One Sided Selection            0.7    0.7   0.835       1.0             3.0
# ENN                           0.95  0.704   0.938       5.0             5.0
# Neighbourhood Cleaning Rule   0.95  0.704   0.938       5.0             5.0
# SMOTE+ENN                     0.95  0.691   0.935       7.0             7.0
# Ramdom Under-Sampler           0.9  0.655   0.908       8.0             8.0
# RandomOverSampler             0.95  0.667    0.93       8.0             8.0
# SMOTE+Tomek                    0.9  0.655   0.908       8.0             8.0
# SMOTE                          0.9  0.643   0.905      11.0            11.0
# ADASYN                        0.95  0.633   0.922      12.0            12.0
#
#                              recall_rank  f1_rank  roc_rank  rank_sum
# Imbalanced                          11.0      6.0      11.0      30.0
# Tomek’s link method                  9.0      3.0       9.0      25.0
# Condensed Nearest Neighbour         11.0      6.0      11.0      30.0
# One Sided Selection                  9.0      3.0       9.0      25.0
# ENN                                  1.0      1.0       1.0      13.0
# Neighbourhood Cleaning Rule          1.0      1.0       1.0      13.0
# SMOTE+ENN                            1.0      5.0       3.0      23.0
# Ramdom Under-Sampler                 6.0      9.0       6.0      37.0
# RandomOverSampler                    1.0      6.0       4.0      27.0
# SMOTE+Tomek                          6.0      9.0       6.0      37.0
# SMOTE                                6.0     11.0       8.0      47.0
# ADASYN                               1.0     12.0       5.0      42.0

# %%
df.sort_values('precision', ascending=False)

# 정밀도도 기본(=imbalanced)과 CNN이 1등, Tomek, One Sided Selection  3등
# Out:
#                             method                   c_m    acc precision  \
# Imbalanced                       -   [[196, 4], [8, 12]]  0.945      0.75
# Condensed Nearest Neighbour  under   [[196, 4], [8, 12]]  0.945      0.75
# Tomek’s link method          under   [[194, 6], [6, 14]]  0.945       0.7
# One Sided Selection          under   [[194, 6], [6, 14]]  0.945       0.7
# ENN                          under  [[185, 15], [1, 19]]  0.927     0.559
# Neighbourhood Cleaning Rule  under  [[185, 15], [1, 19]]  0.927     0.559
# SMOTE+ENN                     over  [[184, 16], [1, 19]]  0.923     0.543
# Ramdom Under-Sampler         under  [[183, 17], [2, 18]]  0.914     0.514
# RandomOverSampler             over  [[182, 18], [1, 19]]  0.914     0.514
# SMOTE+Tomek                   over  [[183, 17], [2, 18]]  0.914     0.514
# SMOTE                         over  [[182, 18], [2, 18]]  0.909       0.5
# ADASYN                        over  [[179, 21], [1, 19]]    0.9     0.475
#
#                             recall     f1 roc_auc  acc_rank  precision_rank  \
# Imbalanced                     0.6  0.667    0.79       1.0             1.0
# Condensed Nearest Neighbour    0.6  0.667    0.79       1.0             1.0
# Tomek’s link method            0.7    0.7   0.835       1.0             3.0
# One Sided Selection            0.7    0.7   0.835       1.0             3.0
# ENN                           0.95  0.704   0.938       5.0             5.0
# Neighbourhood Cleaning Rule   0.95  0.704   0.938       5.0             5.0
# SMOTE+ENN                     0.95  0.691   0.935       7.0             7.0
# Ramdom Under-Sampler           0.9  0.655   0.908       8.0             8.0
# RandomOverSampler             0.95  0.667    0.93       8.0             8.0
# SMOTE+Tomek                    0.9  0.655   0.908       8.0             8.0
# SMOTE                          0.9  0.643   0.905      11.0            11.0
# ADASYN                        0.95  0.633   0.922      12.0            12.0
#
#                              recall_rank  f1_rank  roc_rank  rank_sum
# Imbalanced                          11.0      6.0      11.0      30.0
# Condensed Nearest Neighbour         11.0      6.0      11.0      30.0
# Tomek’s link method                  9.0      3.0       9.0      25.0
# One Sided Selection                  9.0      3.0       9.0      25.0
# ENN                                  1.0      1.0       1.0      13.0
# Neighbourhood Cleaning Rule          1.0      1.0       1.0      13.0
# SMOTE+ENN                            1.0      5.0       3.0      23.0
# Ramdom Under-Sampler                 6.0      9.0       6.0      37.0
# RandomOverSampler                    1.0      6.0       4.0      27.0
# SMOTE+Tomek                          6.0      9.0       6.0      37.0
# SMOTE                                6.0     11.0       8.0      47.0
# ADASYN                               1.0     12.0       5.0      42.0

# %%
df.sort_values('recall', ascending=False)
# ENN, NCR, RandomOverSampler, ADASYN, SMOTE+ENN 1등
# Out:
#                             method                   c_m    acc precision  \
# ENN                          under  [[185, 15], [1, 19]]  0.927     0.559
# Neighbourhood Cleaning Rule  under  [[185, 15], [1, 19]]  0.927     0.559
# RandomOverSampler             over  [[182, 18], [1, 19]]  0.914     0.514
# ADASYN                        over  [[179, 21], [1, 19]]    0.9     0.475
# SMOTE+ENN                     over  [[184, 16], [1, 19]]  0.923     0.543
# Ramdom Under-Sampler         under  [[183, 17], [2, 18]]  0.914     0.514
# SMOTE                         over  [[182, 18], [2, 18]]  0.909       0.5
# SMOTE+Tomek                   over  [[183, 17], [2, 18]]  0.914     0.514
# Tomek’s link method          under   [[194, 6], [6, 14]]  0.945       0.7
# One Sided Selection          under   [[194, 6], [6, 14]]  0.945       0.7
# Imbalanced                       -   [[196, 4], [8, 12]]  0.945      0.75
# Condensed Nearest Neighbour  under   [[196, 4], [8, 12]]  0.945      0.75
#
#                             recall     f1 roc_auc  acc_rank  precision_rank  \
# ENN                           0.95  0.704   0.938       5.0             5.0
# Neighbourhood Cleaning Rule   0.95  0.704   0.938       5.0             5.0
# RandomOverSampler             0.95  0.667    0.93       8.0             8.0
# ADASYN                        0.95  0.633   0.922      12.0            12.0
# SMOTE+ENN                     0.95  0.691   0.935       7.0             7.0
# Ramdom Under-Sampler           0.9  0.655   0.908       8.0             8.0
# SMOTE                          0.9  0.643   0.905      11.0            11.0
# SMOTE+Tomek                    0.9  0.655   0.908       8.0             8.0
# Tomek’s link method            0.7    0.7   0.835       1.0             3.0
# One Sided Selection            0.7    0.7   0.835       1.0             3.0
# Imbalanced                     0.6  0.667    0.79       1.0             1.0
# Condensed Nearest Neighbour    0.6  0.667    0.79       1.0             1.0
#
#                              recall_rank  f1_rank  roc_rank  rank_sum
# ENN                                  1.0      1.0       1.0      13.0
# Neighbourhood Cleaning Rule          1.0      1.0       1.0      13.0
# RandomOverSampler                    1.0      6.0       4.0      27.0
# ADASYN                               1.0     12.0       5.0      42.0
# SMOTE+ENN                            1.0      5.0       3.0      23.0
# Ramdom Under-Sampler                 6.0      9.0       6.0      37.0
# SMOTE                                6.0     11.0       8.0      47.0
# SMOTE+Tomek                          6.0      9.0       6.0      37.0
# Tomek’s link method                  9.0      3.0       9.0      25.0
# One Sided Selection                  9.0      3.0       9.0      25.0
# Imbalanced                          11.0      6.0      11.0      30.0
# Condensed Nearest Neighbour         11.0      6.0      11.0      30.0

# %%
df.sort_values('f1', ascending=False)
# ENN, NCR
# Out:
#                             method                   c_m    acc precision  \
# ENN                          under  [[185, 15], [1, 19]]  0.927     0.559
# Neighbourhood Cleaning Rule  under  [[185, 15], [1, 19]]  0.927     0.559
# Tomek’s link method          under   [[194, 6], [6, 14]]  0.945       0.7
# One Sided Selection          under   [[194, 6], [6, 14]]  0.945       0.7
# SMOTE+ENN                     over  [[184, 16], [1, 19]]  0.923     0.543
# Imbalanced                       -   [[196, 4], [8, 12]]  0.945      0.75
# Condensed Nearest Neighbour  under   [[196, 4], [8, 12]]  0.945      0.75
# RandomOverSampler             over  [[182, 18], [1, 19]]  0.914     0.514
# Ramdom Under-Sampler         under  [[183, 17], [2, 18]]  0.914     0.514
# SMOTE+Tomek                   over  [[183, 17], [2, 18]]  0.914     0.514
# SMOTE                         over  [[182, 18], [2, 18]]  0.909       0.5
# ADASYN                        over  [[179, 21], [1, 19]]    0.9     0.475
#
#                             recall     f1 roc_auc  acc_rank  precision_rank  \
# ENN                           0.95  0.704   0.938       5.0             5.0
# Neighbourhood Cleaning Rule   0.95  0.704   0.938       5.0             5.0
# Tomek’s link method            0.7    0.7   0.835       1.0             3.0
# One Sided Selection            0.7    0.7   0.835       1.0             3.0
# SMOTE+ENN                     0.95  0.691   0.935       7.0             7.0
# Imbalanced                     0.6  0.667    0.79       1.0             1.0
# Condensed Nearest Neighbour    0.6  0.667    0.79       1.0             1.0
# RandomOverSampler             0.95  0.667    0.93       8.0             8.0
# Ramdom Under-Sampler           0.9  0.655   0.908       8.0             8.0
# SMOTE+Tomek                    0.9  0.655   0.908       8.0             8.0
# SMOTE                          0.9  0.643   0.905      11.0            11.0
# ADASYN                        0.95  0.633   0.922      12.0            12.0
#
#                              recall_rank  f1_rank  roc_rank  rank_sum
# ENN                                  1.0      1.0       1.0      13.0
# Neighbourhood Cleaning Rule          1.0      1.0       1.0      13.0
# Tomek’s link method                  9.0      3.0       9.0      25.0
# One Sided Selection                  9.0      3.0       9.0      25.0
# SMOTE+ENN                            1.0      5.0       3.0      23.0
# Imbalanced                          11.0      6.0      11.0      30.0
# Condensed Nearest Neighbour         11.0      6.0      11.0      30.0
# RandomOverSampler                    1.0      6.0       4.0      27.0
# Ramdom Under-Sampler                 6.0      9.0       6.0      37.0
# SMOTE+Tomek                          6.0      9.0       6.0      37.0
# SMOTE                                6.0     11.0       8.0      47.0
# ADASYN                               1.0     12.0       5.0      42.0

# %%
df.sort_values('roc_auc', ascending=False)

#ENN, NCR
# Out:
#                             method                   c_m    acc precision  \
# ENN                          under  [[185, 15], [1, 19]]  0.927     0.559
# Neighbourhood Cleaning Rule  under  [[185, 15], [1, 19]]  0.927     0.559
# SMOTE+ENN                     over  [[184, 16], [1, 19]]  0.923     0.543
# RandomOverSampler             over  [[182, 18], [1, 19]]  0.914     0.514
# ADASYN                        over  [[179, 21], [1, 19]]    0.9     0.475
# Ramdom Under-Sampler         under  [[183, 17], [2, 18]]  0.914     0.514
# SMOTE+Tomek                   over  [[183, 17], [2, 18]]  0.914     0.514
# SMOTE                         over  [[182, 18], [2, 18]]  0.909       0.5
# Tomek’s link method          under   [[194, 6], [6, 14]]  0.945       0.7
# One Sided Selection          under   [[194, 6], [6, 14]]  0.945       0.7
# Imbalanced                       -   [[196, 4], [8, 12]]  0.945      0.75
# Condensed Nearest Neighbour  under   [[196, 4], [8, 12]]  0.945      0.75
#
#                             recall     f1 roc_auc  acc_rank  precision_rank  \
# ENN                           0.95  0.704   0.938       5.0             5.0
# Neighbourhood Cleaning Rule   0.95  0.704   0.938       5.0             5.0
# SMOTE+ENN                     0.95  0.691   0.935       7.0             7.0
# RandomOverSampler             0.95  0.667    0.93       8.0             8.0
# ADASYN                        0.95  0.633   0.922      12.0            12.0
# Ramdom Under-Sampler           0.9  0.655   0.908       8.0             8.0
# SMOTE+Tomek                    0.9  0.655   0.908       8.0             8.0
# SMOTE                          0.9  0.643   0.905      11.0            11.0
# Tomek’s link method            0.7    0.7   0.835       1.0             3.0
# One Sided Selection            0.7    0.7   0.835       1.0             3.0
# Imbalanced                     0.6  0.667    0.79       1.0             1.0
# Condensed Nearest Neighbour    0.6  0.667    0.79       1.0             1.0
#
#                              recall_rank  f1_rank  roc_rank  rank_sum
# ENN                                  1.0      1.0       1.0      13.0
# Neighbourhood Cleaning Rule          1.0      1.0       1.0      13.0
# SMOTE+ENN                            1.0      5.0       3.0      23.0
# RandomOverSampler                    1.0      6.0       4.0      27.0
# ADASYN                               1.0     12.0       5.0      42.0
# Ramdom Under-Sampler                 6.0      9.0       6.0      37.0
# SMOTE+Tomek                          6.0      9.0       6.0      37.0
# SMOTE                                6.0     11.0       8.0      47.0
# Tomek’s link method                  9.0      3.0       9.0      25.0
# One Sided Selection                  9.0      3.0       9.0      25.0
# Imbalanced                          11.0      6.0      11.0      30.0
# Condensed Nearest Neighbour         11.0      6.0      11.0      30.0

# %%
df.sort_values('rank_sum')

# 랭크들의 합(낮을 수록 좋음) 결과, ENN, NCR, SMOTE + ENN 순
# Out:
#                             method                   c_m    acc precision  \
# ENN                          under  [[185, 15], [1, 19]]  0.927     0.559
# Neighbourhood Cleaning Rule  under  [[185, 15], [1, 19]]  0.927     0.559
# SMOTE+ENN                     over  [[184, 16], [1, 19]]  0.923     0.543
# Tomek’s link method          under   [[194, 6], [6, 14]]  0.945       0.7
# One Sided Selection          under   [[194, 6], [6, 14]]  0.945       0.7
# RandomOverSampler             over  [[182, 18], [1, 19]]  0.914     0.514
# Imbalanced                       -   [[196, 4], [8, 12]]  0.945      0.75
# Condensed Nearest Neighbour  under   [[196, 4], [8, 12]]  0.945      0.75
# Ramdom Under-Sampler         under  [[183, 17], [2, 18]]  0.914     0.514
# SMOTE+Tomek                   over  [[183, 17], [2, 18]]  0.914     0.514
# ADASYN                        over  [[179, 21], [1, 19]]    0.9     0.475
# SMOTE                         over  [[182, 18], [2, 18]]  0.909       0.5
#
#                             recall     f1 roc_auc  acc_rank  precision_rank  \
# ENN                           0.95  0.704   0.938       5.0             5.0
# Neighbourhood Cleaning Rule   0.95  0.704   0.938       5.0             5.0
# SMOTE+ENN                     0.95  0.691   0.935       7.0             7.0
# Tomek’s link method            0.7    0.7   0.835       1.0             3.0
# One Sided Selection            0.7    0.7   0.835       1.0             3.0
# RandomOverSampler             0.95  0.667    0.93       8.0             8.0
# Imbalanced                     0.6  0.667    0.79       1.0             1.0
# Condensed Nearest Neighbour    0.6  0.667    0.79       1.0             1.0
# Ramdom Under-Sampler           0.9  0.655   0.908       8.0             8.0
# SMOTE+Tomek                    0.9  0.655   0.908       8.0             8.0
# ADASYN                        0.95  0.633   0.922      12.0            12.0
# SMOTE                          0.9  0.643   0.905      11.0            11.0
#
#                              recall_rank  f1_rank  roc_rank  rank_sum
# ENN                                  1.0      1.0       1.0      13.0
# Neighbourhood Cleaning Rule          1.0      1.0       1.0      13.0
# SMOTE+ENN                            1.0      5.0       3.0      23.0
# Tomek’s link method                  9.0      3.0       9.0      25.0
# One Sided Selection                  9.0      3.0       9.0      25.0
# RandomOverSampler                    1.0      6.0       4.0      27.0
# Imbalanced                          11.0      6.0      11.0      30.0
# Condensed Nearest Neighbour         11.0      6.0      11.0      30.0
# Ramdom Under-Sampler                 6.0      9.0       6.0      37.0
# SMOTE+Tomek                          6.0      9.0       6.0      37.0
# ADASYN                               1.0     12.0       5.0      42.0
# SMOTE                                6.0     11.0       8.0      47.0

# %% [markdown]
# ### 결과 종합
# - 책에서 배우기를 Recall 측면에서 오버샘플링이 언더샘플링보다 좋다고 배웠는데 이번 실습에선 언더샘플링이 효과적이었음
# - 이건 데이터셋에 따라 다를 것으로 보이나 참고할만한 결과라고 생각듦
# - 우선 전반적으로 샘플링기법을 사용하면 정밀도(precision)은 하락, 재현율(recall)과 f1, roc_auc 3개는 상승함
# - Imbalanced Data set & 정밀도를 양보해도 되는 상황에서 샘플링 기법은 효과적일 것으로 보임

# %% [markdown]
# #### imblearn 내의 평가지표
# * 총 3개
# * sensitivity_score (민감도=재현율=TPR, 실제 1에서 1을 예측한 확률)
# * specificity_score (특이도=TNR, 실제 0에서 0을 예측한 확률)
# * sensitivity_specificity_support (민감도, 특이도 2개 리턴)

# %%
from imblearn.metrics import sensitivity_specificity_support
from imblearn.metrics import sensitivity_score, specificity_score
print('민감도:',sensitivity_score(y_imb, model_samp.predict(X_imb)))
print('특이도:', specificity_score(y_imb, model_samp.predict(X_imb)))
print("둘 다:", sensitivity_specificity_support(y_imb, model_samp.predict(X_imb), average='binary'))
# Out:
# 민감도: 0.9
# 특이도: 0.915
# 둘 다: (0.9, 0.915, None)
