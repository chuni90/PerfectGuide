# %%
import requests, json

my_api = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI2YTQ2YzQwMC0xMmFlLTAxMzgtMzYxMS0yOTc0NWRlZGVmNWQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTc4MzEzOTAxLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImxvdmVyMTQ1Ny1nbWFpIn0.d7TlZC7jMTX_aDhV8NcMiPgzAwFCW5x-gWe1ISMwgtg'
match_id = '942beb1d-d704-4a54-ba92-7cbd72e6c1fb'
url = 'https://api.pubg.com/shards/steam/matches/{}'.format(match_id)

header = {
  "Authorization": "Bearer <"+ my_api + ">",
  "Accept": "application/vnd.api+json"
}

r = requests.get(url, headers=header)

# %%
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '{"data":{"type":"match","id":"b6494f4e-7865-4f48-b018-98d5ce8f3ea4","attributes":{"titleId":"bluehole-pubg","shardId":"steam","seasonState":"progress","tags":null,"mapName":"Savage_Main","isCustomMatch":false,"createdAt":"2020-01-04T14:57:22Z","duration":1521,"stats":null,"gameMode":"solo"},"relationships":{"rosters":{"data":[{"type":"roster","id":"38237dce-0c53-46b4-af51-953e2fa01eac"},{"type":"roster","id":"86622696-73d3-452e-8823-dbe667ceb3fb"},{"type":"roster","id":"4c5e6033-0f92-44e5-8a96-f85e9c579017"},{"type":"roster","id":"fceeaae5-4acc-47ee-bc9b-1ca3fe70240b"},{"type":"roster","id":"ad9e6971-c6c5-4a85-814f-47d9be00c758"},{"type":"roster","id":"5d5f6215-4c09-4055-8dcf-8191b27f681e"},{"type":"roster","id":"1c6e263d-61ba-49ae-a46b-828acf881504"},{"type":"roster","id":"6588f03f-3eec-4e72-a052-6023bc47e0e1"},{"type":"roster","id":"efb0d576-f3f1-4979-b0b4-f32ae1bd24a7"},{"type":"roster","id":"7a14d0f7-45ee-411f-9772-56cdd8f77f51"},{"type":"roster","id":"7c6a303d-5a0e-4c46-810c-08a1d476c1e9"},{"type":"roster","id":"2bd38c0c-b5bb-454d-9aff-4900b550a235"},{"type":"roster","id":"2c596613-64e3-49c7-aeb4-e71b5afe4806"},{"type":"roster","id":"aba2646c-e426-44c8-ac94-8d74b169fa8f"},{"type":"roster","id":"3723d612-0c66-46d9-84ef-4ddeb47503b8"},{"type":"roster","id":"128b2b55-4494-413c-aee1-56497d0e182c"},{"type":"roster","id":"a968b2e0-4656-4816-b20c-ee9051bea262"},{"type":"roster","id":"4594ddd3-c8cc-46c8-8afe-8957d5d8072e"},{"type":"roster","id":"52a3e76c-1989-4a57-8789-6da4c8f7ede7"},{"type":"roster","id":"4af9c4c1-d760-4817-a04e-698b4cbdf5f8"},{"type":"roster","id":"35b73141-d302-4b15-9ce8-e6500b26c2c0"},{"type":"roster","id":"a3062ef3-5cc7-437a-ae2b-b2d69e1055b2"},{"type":"roster","id":"e838db99-4ed3-4184-ac7b-f803f778b522"},{"type":"roster","id":"c968bfc3-d315-4dbe-9ce0-22fa0d5cf658"},{"type":"roster","id":"79afd8a8-0cd8-4f3f-9b46-466bcf5f054d"},{"type":"roster","id":"c451a74e-9719-4e4f-b77c-030e24f5d49d"},{"type":"roster","id":"3bbe3f48-77c1-428a-a848-f95a76671c82"},{"type":"roster","id":"824cbae4-44b6-490d-bb56-5623bec15521"},{"type":"roster","id":"7e6ad7b4-0ca6-4ac7-a4c7-fd7fff7b4a27"},{"type":"roster","id":"4b510120-864b-43ea-a3ce-1b0c3a9bbf3f"},{"type":"roster","id":"10945889-6d7b-4990-8dc8-339e2dcba670"},{"type":"roster","id":"6b5e5eaa-746e-4d01-a268-fe492d6cb623"},{"type":"roster","id":"56849a05-4d90-423e-87af-b9bf9dfa525d"},{"type":"roster","id":"728fa275-df37-4902-b262-4bbddadc8ab8"},{"type":"roster","id":"4d3e3bbb-3ee5-44e9-a72a-4cce1f1bc36b"},{"type":"roster","id":"03dcc9c3-8081-4958-bca2-9dbb541fe811"},{"type":"roster","id":"f8e1c91d-6568-4b99-b3d2-6d8d1382a0ac"},{"type":"roster","id":"e446d69d-4ae6-4444-9679-c0e09164fa67"},{"type":"roster","id":"1ac536ca-3d23-4f7f-96b0-116114fc8d00"},{"type":"roster","id":"5e527d19-f794-445e-a852-c6d9948f614d"},{"type":"roster","id":"7450ef2e-ab10-4fc3-be6c-8d5527b26bfc"},{"type":"roster","id":"835eee4e-0925-41ef-9bfc-a292bc173ac9"},{"type":"roster","id":"9c36ce2b-b354-4a6f-9a9f-3f74fc909f88"},{"type":"roster","id":"05286742-fc17-4353-b0be-ed72f98e9f39"},{"type":"roster","id":"26a54e0a-2c94-4ce4-8acf-869a3a11d9d9"},{"type":"roster","id":"2c491ec6-9b78-420d-b8b6-16071a3c3a1c"},{"type":"roster","id":"345c60f5-e130-44c0-a14d-36111674bb62"},{"type":"roster","id":"4134219a-78cf-4372-99cf-8e25ba41cb55"},{"type":"roster","id":"592e946e-8991-4db5-a66e-d7e83d2a2308"},{"type":"roster","id":"05d4fc76-ac43-4d2f-bdd1-cc4b128f6ac0"},{"type":"roster","id":"e2afd632-5f4c-46c8-b7bc-69e155356ff3"},{"type":"roster","id":"cd5e3c2b-d2e9-4bd2-b097-1182f854fbc7"},{"type":"roster","id":"9f1886c6-abf5-4bf1-8ed5-6a3874928ba0"},{"type":"roster","id":"a4f6af6e-9f93-4e3a-ab51-5854f1e60c6d"},{"type":"roster","id":"08b1c068-4dc1-49fb-bf8f-b53ab36fb7a8"},{"type":"roster","id":"c4ce7d24-7ee7-41ca-bcae-1fae2ccd5a6a"},{"type":"roster","id":"e799c1f8-daa3-4270-87b2-a1c8b56da06a"},{"type":"roster","id":"d61f78bd-b4b9-4344-8809-67e59c9225f0"},{"type":"roster","id":"18e4c2fb-5295-4e5d-bac1-290ea2bec82b"},{"type":"rost ...

# %%
j = json.loads(r.text)
j
# Out:
# {'data': {'type': 'match',
#   'id': '942beb1d-d704-4a54-ba92-7cbd72e6c1fb',
#   'attributes': {'isCustomMatch': False,
#    'seasonState': 'progress',
#    'createdAt': '2019-12-28T12:51:28Z',
#    'stats': None,
#    'gameMode': 'squad',
#    'titleId': 'bluehole-pubg',
#    'shardId': 'steam',
#    'tags': None,
#    'duration': 1759,
#    'mapName': 'DihorOtok_Main'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': '8db5f7e1-c885-4dc4-8adb-09d809ef602f'},
#      {'type': 'roster', 'id': 'b7fa5cf2-bcee-4159-a9d6-65a2af677e31'},
#      {'type': 'roster', 'id': 'eef3dd60-caaf-424e-bed1-28a2c08d477e'},
#      {'type': 'roster', 'id': 'fa0ae9ba-c2f7-4f2b-ad56-191cfc0d603e'},
#      {'type': 'roster', 'id': 'e60628f5-d367-4865-822c-a6df2e2078e0'},
#      {'type': 'roster', 'id': '42f4309a-4568-4e0f-b89e-667a9ba893cc'},
#      {'type': 'roster', 'id': 'a6dfdd0c-0200-40fc-9bb7-2081bcd28c21'},
#      {'type': 'roster', 'id': '67250342-970c-4980-a1df-5637b0b48ed8'},
#      {'type': 'roster', 'id': '3baf86fa-0c56-4fd0-8c33-4d2dba34b999'},
#      {'type': 'roster', 'id': '4fe218c1-2a19-4adb-981d-552dbfbd6962'},
#      {'type': 'roster', 'id': '1ef313ab-8850-46c9-9ffc-fa5cd99ee484'},
#      {'type': 'roster', 'id': 'bd0be6f0-3650-48ae-b94d-624eafc168b5'},
#      {'type': 'roster', 'id': '927b2517-0f63-4fe6-9b86-838c980417ed'},
#      {'type': 'roster', 'id': '3aafaa44-08c5-43af-841c-7e93101706ab'},
#      {'type': 'roster', 'id': 'ad3127e6-93dc-4775-bc71-249c45484f9c'},
#      {'type': 'roster', 'id': '5943b47a-5885-4509-83e0-112a993c6c8b'},
#      {'type': 'roster', 'id': '79e59687-96ef-4c20-9dac-3cc470ee4473'},
#      {'type': 'roster', 'id': 'bfa3b933-ca0f-4cdf-a9fb-96ad8ec6ce4d'},
#      {'type': 'roster', 'id': '5dc6a355-f86d-442d-82f3-e435f87a3683'},
#      {'type': 'roster', 'id': '605a3358-d9be-46cc-9f45-c93caf1eb453'},
#      {'type': 'roster', 'id': '5f6010e9-4ce5-4ddd-9ddf-67c1a1cabaa8'},
#      {'type': 'roster', 'id': '6f35355c-3620-4aab-902d-a667b0e74fec'},
#      {'type': 'roster', 'id': 'a23d007f-1244-4c01-8cbf-3e80caa98741'},
#      {'type': 'roster', 'id': '74641656-59a8-4535-b67d-7cf0676e2c35'},
#      {'type': 'roster', 'id': '664da482-403d-4f18-9c60-1d56d1acf24f'},
#      {'type': 'roster', 'id': '71a60a6b-70ee-4acc-9b87-071928d40f52'},
#      {'type': 'roster', 'id': '9618309a-af85-450b-b3a4-c7ff12c31366'},
#      {'type': 'roster', 'id': '26a782f7-a00e-4a06-820b-c72bf8a5ef75'},
#      {'type': 'roster', 'id': 'f37d33e9-2013-402c-8b85-c923200fda9c'}]},
#    'assets': {'data': [{'type': 'asset',
#       'id': '21a76517-2975-11ea-b19c-c2f203cc5701'}]}},
#   'links': {'self': 'https://api.playbattlegrounds.com/shards/steam/matches/942beb1d-d704-4a54-ba92-7cbd72e6c1fb',
#    'schema': ''}},
#  'included': [{'type': 'participant',
#    'id': '6bc67983-e389-4b09-9e99-c22e23af3792',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 62,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Tranquillity-R',
#      'playerId': 'account.35ba8313a05546e888aee8a96834624c',
#      'revives': 0,
#      'rideDistance': 2488.2314,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 930.426,
#      'vehicleDestroys': 0,
#      'walkDistance': 1514.6509,
#      'weaponsAcquired': 6,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '1935243f-2f3b-4179-a596-e36f73301412',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 80,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'GIID-DPS',
#      'playerId': 'account.cc00a21375bd4c0695a9d8a27c3f58e2',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 710.808,
#      'vehicleDestroys': 0,
#      'walkDistance': 34.017254,
#      'weaponsAcquired': 0,
#      'winPlace': 25}}},
#   {'type': 'participant',
#    'id': 'd47be99e-3004-4a16-aefe-5cd0fada7d89',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 5,
#      'damageDealt': 185.84674,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 26,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 30.987904,
#      'name': 'Hola_Amigo7',
#      'playerId': 'account.bf1051adea3d46d78c9412bf49e011ae',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1440.114,
#      'vehicleDestroys': 0,
#      'walkDistance': 2931.2612,
#      'weaponsAcquired': 6,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '0cc4c790-6bbc-41ba-a880-07f0da644d6a',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 124.48839,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 0,
#      'killPlace': 27,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 36.326527,
#      'name': 'koonkang',
#      'playerId': 'account.1d49fa1779684ba3a81641c79f312253',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1357.922,
#      'vehicleDestroys': 0,
#      'walkDistance': 3108.4622,
#      'weaponsAcquired': 4,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'f37d33e9-2013-402c-8b85-c923200fda9c',
#    'attributes': {'stats': {'rank': 10, 'teamId': 18},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '72f2cf86-4fdd-4ee3-9a25-324ad54901bd'},
#       {'type': 'participant', 'id': '04cf8762-45e3-4ba0-99bf-b61b3d2c929d'},
#       {'type': 'participant',
#        'id': '51a0e41e-7552-4ff6-9312-bb8a61f49792'}]}}},
#   {'type': 'participant',
#    'id': '3aa3588f-0dfb-4f57-96fb-bf407c461159',
#    'attributes': {'stats': {'DBNOs': 4,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 515.8151,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 14,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 45.186478,
#      'name': 'Johae',
#      'playerId': 'account.36744d2e42cb455687bddc684d5df69c',
#      'revives': 0,
#      'rideDistance': 354.73395,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 886.602,
#      'vehicleDestroys': 0,
#      'walkDistance': 1487.1382,
#      'weaponsAcquired': 4,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'b797c8da-4743-49c2-97fa-ff136e7d4c52',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 131.6411,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 50,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'tyottomatte',
#      'playerId': 'account.23394107f9f642d5aa76c72f0660c92d',
#      'revives': 0,
#      'rideDistance': 2047.2512,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1496.996,
#      'vehicleDestroys': 0,
#      'walkDistance': 2709.975,
#      'weaponsAcquired': 4,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '1dd833ec-cec6-4eab-b3c7-8117f660240c',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 54,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'basashi215',
#      'playerId': 'account.6845b9a7234f44bd8c66efe7594c6d4a',
#      'revives': 0,
#      'rideDistance': 2082.7559,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1434.762,
#      'vehicleDestroys': 0,
#      'walkDistance': 2171.854,
#      'weaponsAcquired': 6,
#      'winPlace': 6},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '51a0e41e-7552-4ff6-9312-bb8a61f49792',
#    'attributes': {'stats': {'DBNOs': 4,
#      'assists': 1,
#      'boosts': 5,
#      'damageDealt': 361.26764,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 8,
#      'killPlace': 8,
#      'killStreaks': 1,
#      'kills': 3,
#      'longestKill': 24.1924,
#      'name': 'Yuja-__-',
#      'playerId': 'account.229b8299b7344b1494eb534436f54c2a',
#      'revives': 0,
#      'rideDistance': 2988.2334,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1070.94,
#      'vehicleDestroys': 0,
#      'walkDistance': 1214.586,
#      'weaponsAcquired': 9,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '67250342-970c-4980-a1df-5637b0b48ed8',
#    'attributes': {'stats': {'rank': 1, 'teamId': 14},
#     'won': 'true',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '9f22bb88-df66-4ab9-b257-39b83937d7c9'},
#       {'type': 'participant', 'id': 'dbc485f6-c8ea-4a92-a05b-8dfc38d95696'},
#       {'type': 'participant', 'id': 'eb726116-7875-495d-8ec5-cbdebbf03281'},
#       {'type': 'participant',
#        'id': '66c941c4-faff-45f8-ba9b-766c3e747960'}]}}},
#   {'type': 'roster',
#    'id': 'a23d007f-1244-4c01-8cbf-3e80caa98741',
#    'attributes': {'stats': {'rank': 16, 'teamId': 20},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '10b0081d-66b6-4bee-ae6b-bab84025b3ea'},
#       {'type': 'participant', 'id': '27ccae02-4353-4a26-ab47-043fa0ae16f2'},
#       {'type': 'participant', 'id': 'cb16d216-0853-4ede-a9d8-2f26121fbfa4'},
#       {'type': 'participant',
#        'id': 'd78d5665-e9f0-47ad-8160-e7c2a444f183'}]}}},
#   {'type': 'participant',
#    'id': 'd9897bb8-2447-4e4f-8b6b-92227cda7a4c',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 73,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'C8_CUNT',
#      'playerId': 'account.7aa69ab4c4444035a1864adcc777e361',
#      'revives': 0,
#      'rideDistance': 2087.502,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 640.267,
#      'vehicleDestroys': 0,
#      'walkDistance': 1098.4404,
#      'weaponsAcquired': 2,
#      'winPlace': 20},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '3baf86fa-0c56-4fd0-8c33-4d2dba34b999',
#    'attributes': {'stats': {'rank': 13, 'teamId': 13},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '6bc67983-e389-4b09-9e99-c22e23af3792'},
#       {'type': 'participant', 'id': 'd35ea177-ed95-4f06-a1d3-78576c0665b8'},
#       {'type': 'participant', 'id': 'b4bb6891-6649-45b3-83e8-eaa5863f2924'},
#       {'type': 'participant',
#        'id': 'ad7c93f7-d05a-4e8f-a391-133a7a3171e9'}]}}},
#   {'type': 'roster',
#    'id': '3aafaa44-08c5-43af-841c-7e93101706ab',
#    'attributes': {'stats': {'rank': 20, 'teamId': 15},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '8693362f-19fc-4a43-9a33-de29dcb69bdc'},
#       {'type': 'participant', 'id': 'd9897bb8-2447-4e4f-8b6b-92227cda7a4c'},
#       {'type': 'participant',
#        'id': '799f7eed-a5df-4d4c-a4fe-8a5c3c38b050'}]}}},
#   {'type': 'roster',
#    'id': '79e59687-96ef-4c20-9dac-3cc470ee4473',
#    'attributes': {'shardId': 'steam',
#     'stats': {'rank': 8, 'teamId': 11},
#     'won': 'false'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '83c6133e-a57b-488e-b848-4cd899d56d41'},
#       {'type': 'participant', 'id': 'b108207c-50ea-479d-8a4f-25542b631180'},
#       {'type': 'participant', 'id': 'fe405edc-77d0-442c-9224-862c346a60d5'},
#       {'type': 'participant',
#        'id': '83b52ae5-eb01-4f74-85d8-b3766207dd1c'}]}}},
#   {'type': 'participant',
#    'id': 'ede56ced-bcd2-4d11-9b1c-42c346eb14ba',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 156.2652,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 1,
#      'killPlace': 25,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 39.314415,
#      'name': 'crazycho1031',
#      'playerId': 'account.d9abfb4c21a4439cbfaffa8fddbae542',
#      'revives': 0,
#      'rideDistance': 1423.7767,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 747.885,
#      'vehicleDestroys': 0,
#      'walkDistance': 1176.609,
#      'weaponsAcquired': 4,
#      'winPlace': 5},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '6bbf99a1-3bdb-4d6e-9f02-8ca2c6964d95',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 50.75992,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 48,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'gusdlts',
#      'playerId': 'account.22412bd2770740ef9bd73787ae202179',
#      'revives': 0,
#      'rideDistance': 2910.5264,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1710.103,
#      'vehicleDestroys': 0,
#      'walkDistance': 2622.4966,
#      'weaponsAcquired': 5,
#      'winPlace': 2},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': 'c4976aa5-9d16-455f-9b94-6cfef872fe8e',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 213.35,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 69,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ggobooge__',
#      'playerId': 'account.20807bb3256743bda83cb8951a21fd13',
#      'revives': 0,
#      'rideDistance': 3840.9668,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 684.869,
#      'vehicleDestroys': 0,
#      'walkDistance': 629.304,
#      'weaponsAcquired': 6,
#      'winPlace': 19},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '52a87de4-6c46-474b-b0ea-8eb89fa41e3a',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 82,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'SSSangKKK',
#      'playerId': 'account.6e518ad5a6df4c8c89b0850c55255e8d',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 309.586,
#      'vehicleDestroys': 0,
#      'walkDistance': 277.80814,
#      'weaponsAcquired': 5,
#      'winPlace': 25}}},
#   {'type': 'participant',
#    'id': '66c941c4-faff-45f8-ba9b-766c3e747960',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 2,
#      'damageDealt': 141.75749,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 46,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'dunhillgood',
#      'playerId': 'account.a6848d1f17684b158adaf67fe6504a6d',
#      'revives': 0,
#      'rideDistance': 3164.2197,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1759.119,
#      'vehicleDestroys': 0,
#      'walkDistance': 2115.0205,
#      'weaponsAcquired': 4,
#      'winPlace': 1}}},
#   {'type': 'participant',
#    'id': '88528c1b-c7f7-4b72-91d1-0c20a5325ece',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 51,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'chap-_-',
#      'playerId': 'account.cb0e037f9d454d1783c91b91e250e58d',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 78.762,
#      'vehicleDestroys': 0,
#      'walkDistance': 2.1475675,
#      'weaponsAcquired': 1,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '9f22bb88-df66-4ab9-b257-39b83937d7c9',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 3,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 744.03894,
#      'deathType': 'alive',
#      'headshotKills': 0,
#      'heals': 7,
#      'killPlace': 1,
#      'killStreaks': 2,
#      'kills': 8,
#      'longestKill': 80.46222,
#      'name': 'zzommanzaza',
#      'playerId': 'account.cc2756f5781a4bf4ae4b93dcc4718f2c',
#      'revives': 2,
#      'rideDistance': 3144.1619,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1759.119,
#      'vehicleDestroys': 0,
#      'walkDistance': 1844.2612,
#      'weaponsAcquired': 3,
#      'winPlace': 1},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '8f999867-96b6-4211-b131-fdb2fe3c06e3',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 156.42078,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 19,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 10.439331,
#      'name': 'evening05',
#      'playerId': 'account.605b652650694dd682e356d6059e16e8',
#      'revives': 1,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 840.812,
#      'vehicleDestroys': 0,
#      'walkDistance': 1769.2063,
#      'weaponsAcquired': 5,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '04cf8762-45e3-4ba0-99bf-b61b3d2c929d',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 8.869999,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 0,
#      'killPlace': 30,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 29.33605,
#      'name': 'Garp-_-',
#      'playerId': 'account.e81f3f67d08642f5ada9fddc43bc4261',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 308.182,
#      'vehicleDestroys': 0,
#      'walkDistance': 99.12041,
#      'weaponsAcquired': 3,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'fa0ae9ba-c2f7-4f2b-ad56-191cfc0d603e',
#    'attributes': {'won': 'false',
#     'shardId': 'steam',
#     'stats': {'rank': 12, 'teamId': 1}},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'b1b0c581-ef8d-43a1-9d2e-229127ba0ccd'},
#       {'type': 'participant', 'id': '609ae8d9-25a8-44a2-b8c2-d81100ecefc5'},
#       {'type': 'participant', 'id': 'ba852b8e-b366-431b-bcd1-0694792ccb2a'},
#       {'type': 'participant',
#        'id': 'ae917b6b-6c15-4ce2-8558-d9c5ddbebccb'}]}}},
#   {'type': 'asset',
#    'id': '21a76517-2975-11ea-b19c-c2f203cc5701',
#    'attributes': {'name': 'telemetry',
#     'description': '',
#     'createdAt': '2019-12-28T13:22:44Z',
#     'URL': 'https://telemetry-cdn.playbattlegrounds.com/bluehole-pubg/steam/2019/12/28/13/22/21a76517-2975-11ea-b19c-c2f203cc5701-telemetry.json'}},
#   {'type': 'participant',
#    'id': '93ff38a7-3ca7-42b9-8f0f-19e1adcb3bf4',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 103.83443,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 44,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 73.40395,
#      'name': 'Haruka_Web',
#      'playerId': 'account.b776a2ade7b24ad0aac3e5057d9d24f5',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 101.507,
#      'vehicleDestroys': 0,
#      'walkDistance': 43.891197,
#      'weaponsAcquired': 2,
#      'winPlace': 27},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'fe405edc-77d0-442c-9224-862c346a60d5',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 3,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 442,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 5,
#      'killStreaks': 1,
#      'kills': 4,
#      'longestKill': 101.31421,
#      'name': 'AFTV_HingPong',
#      'playerId': 'account.29673f8b762e46d8bb537d91c46de276',
#      'revives': 0,
#      'rideDistance': 754.4724,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1251.406,
#      'vehicleDestroys': 0,
#      'walkDistance': 3703.9407,
#      'weaponsAcquired': 6,
#      'winPlace': 8}}},
#   {'type': 'participant',
#    'id': '51f7f2cd-dd8b-4f4a-be05-43673dd1c5a8',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 3,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 281.28256,
#      'deathType': 'byplayer',
#      'headshotKills': 2,
#      'heals': 0,
#      'killPlace': 22,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 44.83465,
#      'name': 'Mao000',
#      'playerId': 'account.1ea31233bb044ad8ac3281d78efbc6ff',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 126.511,
#      'vehicleDestroys': 0,
#      'walkDistance': 66.2424,
#      'weaponsAcquired': 1,
#      'winPlace': 27},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '73169f12-6df6-432f-b55b-e4fb57ec2378',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 90,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Lacle',
#      'playerId': 'account.0594713fe9f54c279c16cac6821abacf',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 175.055,
#      'vehicleDestroys': 0,
#      'walkDistance': 108.01022,
#      'weaponsAcquired': 2,
#      'winPlace': 27},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'b108207c-50ea-479d-8a4f-25542b631180',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 7,
#      'damageDealt': 122.89,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 7,
#      'killPlace': 28,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 14.011923,
#      'name': 'AFTV_HANNA',
#      'playerId': 'account.bd25352ad1624207a29d05e160b7a5a7',
#      'revives': 1,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1379.483,
#      'vehicleDestroys': 0,
#      'walkDistance': 4677.7783,
#      'weaponsAcquired': 9,
#      'winPlace': 8},
#     'actor': ''}},
#   {'type': 'roster',
#    'id': '42f4309a-4568-4e0f-b89e-667a9ba893cc',
#    'attributes': {'stats': {'rank': 21, 'teamId': 10},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'c36c1cad-1a92-448d-820d-783dd24d1890'},
#       {'type': 'participant', 'id': 'ad76fbe4-50ed-41c2-acdf-62f7c4f2538c'},
#       {'type': 'participant', 'id': '938056ad-55fd-4f71-9b48-95ede3973dba'},
#       {'type': 'participant',
#        'id': '4d583f9f-0b73-405e-91cf-3be8cf66efbe'}]}}},
#   {'type': 'roster',
#    'id': '5dc6a355-f86d-442d-82f3-e435f87a3683',
#    'attributes': {'stats': {'rank': 23, 'teamId': 16},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'b7f03e04-0f86-49ce-b6d1-cb91d3f1ac97'},
#       {'type': 'participant', 'id': 'b8ebf12c-8921-4b18-bb8e-ced81221b612'},
#       {'type': 'participant',
#        'id': '72932ceb-acd0-43e4-9e6b-9e17caf17006'}]}}},
#   {'type': 'participant',
#    'id': 'ad76fbe4-50ed-41c2-acdf-62f7c4f2538c',
#    'attributes': {'stats': {'DBNOs': 3,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 401.91522,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 0,
#      'killPlace': 9,
#      'killStreaks': 1,
#      'kills': 3,
#      'longestKill': 27.297188,
#      'name': 'F-Killer97',
#      'playerId': 'account.1aa8eb8fa2694d35a1b0f573838b0aae',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 593.052,
#      'vehicleDestroys': 0,
#      'walkDistance': 169.83012,
#      'weaponsAcquired': 4,
#      'winPlace': 21},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'cb16d216-0853-4ede-a9d8-2f26121fbfa4',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 64,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'FINNGUM',
#      'playerId': 'account.1bc7205c9ddf48d68e6b32d4e1e2ed51',
#      'revives': 0,
#      'rideDistance': 1340.5513,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 656.316,
#      'vehicleDestroys': 0,
#      'walkDistance': 909.94086,
#      'weaponsAcquired': 9,
#      'winPlace': 16},
#     'actor': ''}},
#   {'type': 'roster',
#    'id': 'a6dfdd0c-0200-40fc-9bb7-2081bcd28c21',
#    'attributes': {'stats': {'rank': 5, 'teamId': 28},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '3aa3588f-0dfb-4f57-96fb-bf407c461159'},
#       {'type': 'participant', 'id': 'f946039e-d063-4a04-bec9-eeffcfc31c10'},
#       {'type': 'participant', 'id': 'ede56ced-bcd2-4d11-9b1c-42c346eb14ba'},
#       {'type': 'participant',
#        'id': '71069593-dfca-4c92-acb3-4af910948092'}]}}},
#   {'type': 'roster',
#    'id': '664da482-403d-4f18-9c60-1d56d1acf24f',
#    'attributes': {'stats': {'rank': 19, 'teamId': 21},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': '8f15169c-aece-44cc-817f-83dd0740dc32'},
#       {'type': 'participant', 'id': 'c4976aa5-9d16-455f-9b94-6cfef872fe8e'},
#       {'type': 'participant', 'id': '1fc5ce73-86cd-4ade-8b84-6c267db9c5a9'}]},
#     'team': {'data': None}}},
#   {'type': 'participant',
#    'id': 'e7c7c005-2e7a-4a4c-97b2-17accd633d55',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 79,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Mr_1000',
#      'playerId': 'account.8569aacec8f2464693cdcf568ac40f1f',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 319.83,
#      'vehicleDestroys': 0,
#      'walkDistance': 581.397,
#      'weaponsAcquired': 4,
#      'winPlace': 24}}},
#   {'type': 'participant',
#    'id': '8d960bb9-91d1-400d-9142-ff9795867d4e',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 34.35994,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 97,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'lmeixi',
#      'playerId': 'account.91183ce4b79b47c7b1de66a95d97e098',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 132.073,
#      'vehicleDestroys': 0,
#      'walkDistance': 48.053204,
#      'weaponsAcquired': 1,
#      'winPlace': 29},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '3aedf3a7-c7e4-4989-b736-2c904ae11eea',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 146,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 98,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Boss573',
#      'playerId': 'account.3fe6266bcfa94c009201b1bfc0e8667a',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 128.319,
#      'vehicleDestroys': 0,
#      'walkDistance': 37.724194,
#      'weaponsAcquired': 2,
#      'winPlace': 29},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '72f2cf86-4fdd-4ee3-9a25-324ad54901bd',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 1,
#      'boosts': 2,
#      'damageDealt': 207.09999,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 11,
#      'killPlace': 17,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 45.792725,
#      'name': 'Another_Lv_',
#      'playerId': 'account.bbe12e905b5e44dd9357afb71107fd47',
#      'revives': 0,
#      'rideDistance': 2490.3003,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 835.764,
#      'vehicleDestroys': 0,
#      'walkDistance': 1235.441,
#      'weaponsAcquired': 7,
#      'winPlace': 10},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '927b2517-0f63-4fe6-9b86-838c980417ed',
#    'attributes': {'stats': {'rank': 25, 'teamId': 6},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '8d960bb9-91d1-400d-9142-ff9795867d4e'},
#       {'type': 'participant', 'id': '1935243f-2f3b-4179-a596-e36f73301412'},
#       {'type': 'participant', 'id': 'd6e5b285-52d8-4bb9-807f-4a7a1c97dd90'},
#       {'type': 'participant',
#        'id': 'd0ac8e91-cb0c-4bbf-93cc-6c0b45197e23'}]}}},
#   {'type': 'roster',
#    'id': '605a3358-d9be-46cc-9f45-c93caf1eb453',
#    'attributes': {'stats': {'rank': 26, 'teamId': 26},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '726cccfa-657e-4a55-be7a-624ed24e8635'},
#       {'type': 'participant', 'id': 'e4e97dd3-a120-4ad9-bc65-88dfc97594ec'},
#       {'type': 'participant',
#        'id': 'c3c7b06b-c96e-4466-9ba5-87ffe935606f'}]}}},
#   {'type': 'participant',
#    'id': '9ce9a42c-cfa4-40b1-9ede-66b0c7555dcf',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 5,
#      'damageDealt': 304.60498,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 1,
#      'killPlace': 16,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 12.992856,
#      'name': 'rlatjdah',
#      'playerId': 'account.85154273261f4c14805f2274a384551d',
#      'revives': 0,
#      'rideDistance': 3068.5134,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1369.331,
#      'vehicleDestroys': 0,
#      'walkDistance': 2298.9539,
#      'weaponsAcquired': 6,
#      'winPlace': 9},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '2ff1d435-4b80-4826-b77f-279df2e5aac6',
#    'attributes': {'stats': {'DBNOs': 3,
#      'assists': 2,
#      'boosts': 5,
#      'damageDealt': 389.60327,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 1,
#      'killPlace': 13,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 72.00772,
#      'name': 'pc4009',
#      'playerId': 'account.7a98196638df484bae562a4b11e3f631',
#      'revives': 0,
#      'rideDistance': 2586.5476,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1750.952,
#      'vehicleDestroys': 0,
#      'walkDistance': 2753.9182,
#      'weaponsAcquired': 10,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '22d01e62-6ab7-4c1c-a75c-56e13dd037ec',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 85.97987,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 47,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Luih615',
#      'playerId': 'account.2fc38415201c42519d09d8ef58b77534',
#      'revives': 0,
#      'rideDistance': 2735.1672,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1750.958,
#      'vehicleDestroys': 0,
#      'walkDistance': 2427.0037,
#      'weaponsAcquired': 5,
#      'winPlace': 2},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'b1b0c581-ef8d-43a1-9d2e-229127ba0ccd',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 67,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Windy1219',
#      'playerId': 'account.14e7690570f941e58a02bb3476d42aa7',
#      'revives': 0,
#      'rideDistance': 1849.9801,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 799.852,
#      'vehicleDestroys': 0,
#      'walkDistance': 817.1648,
#      'weaponsAcquired': 3,
#      'winPlace': 17}}},
#   {'type': 'participant',
#    'id': '5f527eb9-2562-43a9-84c4-6d90210b330f',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 181.29485,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 21,
#      'killStreaks': 2,
#      'kills': 2,
#      'longestKill': 33.62933,
#      'name': 'sybog',
#      'playerId': 'account.e6b1d6921aa64344a6fee3c4018ac30c',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 680.939,
#      'vehicleDestroys': 1,
#      'walkDistance': 1925.9052,
#      'weaponsAcquired': 7,
#      'winPlace': 19},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'b7fa5cf2-bcee-4159-a9d6-65a2af677e31',
#    'attributes': {'won': 'false',
#     'shardId': 'steam',
#     'stats': {'rank': 28, 'teamId': 7}},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '5f43773b-ece9-44dc-a18b-1dda0a4a37da'},
#       {'type': 'participant', 'id': '0a822d5e-4f75-419d-b917-dd089dc0bcb6'},
#       {'type': 'participant', 'id': '8381f514-3f9f-4d3f-9842-0e70fb1fb0b0'},
#       {'type': 'participant',
#        'id': '1add0f13-912f-4442-a9ba-24885bb43296'}]}}},
#   {'type': 'participant',
#    'id': '163a55d2-5058-4cd9-b0d7-1155fcec4a9f',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 38.335,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 57,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'couque_dasse_',
#      'playerId': 'account.3c74c4d33fdd4265ad562983e86d19a4',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 352.146,
#      'vehicleDestroys': 0,
#      'walkDistance': 275.8131,
#      'weaponsAcquired': 3,
#      'winPlace': 9},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '5f43773b-ece9-44dc-a18b-1dda0a4a37da',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 73.21,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 45,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 4.4080653,
#      'name': 'YANGZAIFDV',
#      'playerId': 'account.fb7ffbf3e96f4e8b9bbdaaa893e80590',
#      'revives': 2,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 157.155,
#      'vehicleDestroys': 0,
#      'walkDistance': 62.39378,
#      'weaponsAcquired': 1,
#      'winPlace': 28},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'c96dc950-67e5-4035-93cc-88cc55c293f6',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 49,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'tikaisan',
#      'playerId': 'account.b2bcd4ce22474ef6aac1f7ba06ecfa0d',
#      'revives': 0,
#      'rideDistance': 1814.639,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1474.065,
#      'vehicleDestroys': 0,
#      'walkDistance': 2236.4172,
#      'weaponsAcquired': 7,
#      'winPlace': 3}}},
#   {'type': 'participant',
#    'id': 'd0ac8e91-cb0c-4bbf-93cc-6c0b45197e23',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 71.909996,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 99,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Pokemon_diaoxisi',
#      'playerId': 'account.479f1939078c42289e33756a4ff216ac',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 120.674,
#      'vehicleDestroys': 0,
#      'walkDistance': 32.687485,
#      'weaponsAcquired': 1,
#      'winPlace': 29},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': 'bd0be6f0-3650-48ae-b94d-624eafc168b5',
#    'attributes': {'stats': {'rank': 3, 'teamId': 3},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'c96dc950-67e5-4035-93cc-88cc55c293f6'},
#       {'type': 'participant', 'id': 'b797c8da-4743-49c2-97fa-ff136e7d4c52'},
#       {'type': 'participant', 'id': '6c7cb04c-2a18-4d3d-bfcb-ab86e5c910c6'},
#       {'type': 'participant',
#        'id': '1dd833ec-cec6-4eab-b3c7-8117f660240c'}]}}},
#   {'type': 'participant',
#    'id': '0a822d5e-4f75-419d-b917-dd089dc0bcb6',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 216.32501,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 91,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'wrewerwe',
#      'playerId': 'account.e3b5281565bd4fc5a9d6c40c6d3c7c0d',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 185.614,
#      'vehicleDestroys': 0,
#      'walkDistance': 66.514465,
#      'weaponsAcquired': 2,
#      'winPlace': 28},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'dbc485f6-c8ea-4a92-a05b-8dfc38d95696',
#    'attributes': {'stats': {'DBNOs': 3,
#      'assists': 1,
#      'boosts': 9,
#      'damageDealt': 558.9092,
#      'deathType': 'alive',
#      'headshotKills': 1,
#      'heals': 5,
#      'killPlace': 3,
#      'killStreaks': 1,
#      'kills': 5,
#      'longestKill': 114.07283,
#      'name': 'HeungMin-7',
#      'playerId': 'account.c549afd3dd804d4095a3fe9c8c91b30a',
#      'revives': 1,
#      'rideDistance': 5734.3154,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1759.119,
#      'vehicleDestroys': 0,
#      'walkDistance': 2097.7354,
#      'weaponsAcquired': 5,
#      'winPlace': 1},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '6c7cb04c-2a18-4d3d-bfcb-ab86e5c910c6',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 40.93372,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 24,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 65.60234,
#      'name': 'Tenki01',
#      'playerId': 'account.4831737620fa4a8191cfa0e289792ae9',
#      'revives': 0,
#      'rideDistance': 2194.9336,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1562.432,
#      'vehicleDestroys': 0,
#      'walkDistance': 2643.747,
#      'weaponsAcquired': 16,
#      'winPlace': 3},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8693362f-19fc-4a43-9a33-de29dcb69bdc',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 71,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'K_Search-_-',
#      'playerId': 'account.26f635386f85442c9ab80efb8f3be6ef',
#      'revives': 0,
#      'rideDistance': 1652.239,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 642.32,
#      'vehicleDestroys': 0,
#      'walkDistance': 1476.9889,
#      'weaponsAcquired': 3,
#      'winPlace': 20},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '27ccae02-4353-4a26-ab47-043fa0ae16f2',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 68,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'JINTAE__08',
#      'playerId': 'account.388dba0df8214d628af5e93e84eafbf3',
#      'revives': 0,
#      'rideDistance': 2074.8718,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 782.633,
#      'vehicleDestroys': 0,
#      'walkDistance': 810.71234,
#      'weaponsAcquired': 5,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '26a782f7-a00e-4a06-820b-c72bf8a5ef75',
#    'attributes': {'shardId': 'steam',
#     'stats': {'rank': 6, 'teamId': 5},
#     'won': 'false'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'd47be99e-3004-4a16-aefe-5cd0fada7d89'},
#       {'type': 'participant',
#        'id': '0cc4c790-6bbc-41ba-a880-07f0da644d6a'}]}}},
#   {'type': 'participant',
#    'id': 'ae917b6b-6c15-4ce2-8558-d9c5ddbebccb',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 61,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ckdgud11',
#      'playerId': 'account.ce9e872c93b848e892d4d512ea6ea036',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 950.976,
#      'vehicleDestroys': 0,
#      'walkDistance': 2889.4194,
#      'weaponsAcquired': 4,
#      'winPlace': 12},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '83b52ae5-eb01-4f74-85d8-b3766207dd1c',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 1,
#      'damageDealt': 100,
#      'deathType': 'byzone',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 29,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 52.175278,
#      'name': 'AFTV_Blue',
#      'playerId': 'account.d1d25588aacc40a4bdf7979d6f989032',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 872.024,
#      'vehicleDestroys': 1,
#      'walkDistance': 3085.4119,
#      'weaponsAcquired': 4,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '10b0081d-66b6-4bee-ae6b-bab84025b3ea',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 53.87253,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 1,
#      'killPlace': 33,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 92.00243,
#      'name': 'SW260',
#      'playerId': 'account.27b5f3b20b8140cc8513122d79ee40ed',
#      'revives': 0,
#      'rideDistance': 1607.3358,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 876.021,
#      'vehicleDestroys': 0,
#      'walkDistance': 1759.8639,
#      'weaponsAcquired': 6,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8381f514-3f9f-4d3f-9842-0e70fb1fb0b0',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 93,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Axzv_pnuoc6',
#      'playerId': 'account.2d27ad034c794e4c891a9102c63f83fb',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 160.502,
#      'vehicleDestroys': 0,
#      'walkDistance': 36.490494,
#      'weaponsAcquired': 0,
#      'winPlace': 28},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'ba852b8e-b366-431b-bcd1-0694792ccb2a',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 66,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Essenitial_Art',
#      'playerId': 'account.0f9d15646c694580a724034cd5743010',
#      'revives': 0,
#      'rideDistance': 1507.5613,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 800.211,
#      'vehicleDestroys': 0,
#      'walkDistance': 980.4625,
#      'weaponsAcquired': 7,
#      'winPlace': 17},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'eb726116-7875-495d-8ec5-cbdebbf03281',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 89.238846,
#      'deathType': 'byplayer',
#      'headshotKills': 1,
#      'heals': 0,
#      'killPlace': 23,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 276.0476,
#      'name': 'MOZOO',
#      'playerId': 'account.b9003e3ea0164ed7938a8b5038a33e2e',
#      'revives': 0,
#      'rideDistance': 3447.211,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1450.202,
#      'vehicleDestroys': 0,
#      'walkDistance': 1420.8345,
#      'weaponsAcquired': 7,
#      'winPlace': 1},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '83c6133e-a57b-488e-b848-4cd899d56d41',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 284.58328,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 5,
#      'killPlace': 15,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 65.873116,
#      'name': 'AFTV_Coni',
#      'playerId': 'account.9f96e1fd6e0c4f37989e3a9c78e22fc3',
#      'revives': 1,
#      'rideDistance': 754.09485,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1373.104,
#      'vehicleDestroys': 0,
#      'walkDistance': 3906.1438,
#      'weaponsAcquired': 6,
#      'winPlace': 8},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '72932ceb-acd0-43e4-9e6b-9e17caf17006',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 1,
#      'boosts': 0,
#      'damageDealt': 35.64,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 76,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'ThanksT0',
#      'playerId': 'account.ee27c799f37546f7899b111e89be1e8a',
#      'revives': 0,
#      'rideDistance': 0,
# ...
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 904.003,
#      'vehicleDestroys': 0,
#      'walkDistance': 491.96014,
#      'weaponsAcquired': 5,
#      'winPlace': 22},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '609ae8d9-25a8-44a2-b8c2-d81100ecefc5',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 203.16356,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 34,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 6.676318,
#      'name': 'Jji--Bam_KYH',
#      'playerId': 'account.ba2bcb7548f348e6ad9ca9149e3bac30',
#      'revives': 3,
#      'rideDistance': 1559.6813,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 843.389,
#      'vehicleDestroys': 0,
#      'walkDistance': 1007.8982,
#      'weaponsAcquired': 10,
#      'winPlace': 16},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'dcbdff5b-e8c8-48da-b190-ac69167eed1d',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 81,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'SecretShop',
#      'playerId': 'account.82496f03b52f47718fe6b7ff8fbd6179',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 309.59,
#      'vehicleDestroys': 0,
#      'walkDistance': 148.99103,
#      'weaponsAcquired': 4,
#      'winPlace': 25},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'b4bb6891-6649-45b3-83e8-eaa5863f2924',
#    'attributes': {'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 200,
#      'deathType': 'suicide',
#      'headshotKills': 1,
#      'heals': 1,
#      'killPlace': 18,
#      'killStreaks': 1,
#      'kills': 2,
#      'longestKill': 17.956171,
#      'name': 'Lsgo-6',
#      'playerId': 'account.6cd071693f78432cb2c970a6490b56ae',
#      'revives': 0,
#      'rideDistance': 2500.0344,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 1,
#      'timeSurvived': 930.429,
#      'vehicleDestroys': 0,
#      'walkDistance': 1314.6086,
#      'weaponsAcquired': 7,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '1dedea46-d281-4361-a65c-ddbfc9d17996',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 63,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'PUBG_KAF',
#      'playerId': 'account.5cb617897a25406d8c1f9865b5145865',
#      'revives': 0,
#      'rideDistance': 4711.239,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 878.514,
#      'vehicleDestroys': 0,
#      'walkDistance': 1062.8689,
#      'weaponsAcquired': 4,
#      'winPlace': 15},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '71a60a6b-70ee-4acc-9b87-071928d40f52',
#    'attributes': {'stats': {'rank': 22, 'teamId': 25},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '6c6be734-53c4-48aa-b2fc-a35886b1ba2d'},
#       {'type': 'participant', 'id': '51f7f2cd-dd8b-4f4a-be05-43673dd1c5a8'},
#       {'type': 'participant', 'id': '8ef74080-4dca-4b65-98a9-a35a27b8564b'},
#       {'type': 'participant',
#        'id': '169e1d10-ea02-42ae-ae32-9f7a713e5bf8'}]}}},
#   {'type': 'participant',
#    'id': 'b8ebf12c-8921-4b18-bb8e-ced81221b612',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 100,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 42,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 5.373112,
#      'name': 'fnzlsla',
#      'playerId': 'account.ea175ac962b74ec488cba72a5d12ab55',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 287.505,
#      'vehicleDestroys': 0,
#      'walkDistance': 230.35535,
#      'weaponsAcquired': 4,
#      'winPlace': 23},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '06e3a904-8be5-4465-ae98-20c946e7c022',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 6,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 15,
#      'killPlace': 58,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'dlrldnd666',
#      'playerId': 'account.c34e13bc9b914b52a4631f532022fb0a',
#      'revives': 0,
#      'rideDistance': 4539.921,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 990.672,
#      'vehicleDestroys': 0,
#      'walkDistance': 1663.1177,
#      'weaponsAcquired': 8,
#      'winPlace': 11},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '938056ad-55fd-4f71-9b48-95ede3973dba',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 100,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'batleBPS',
#      'playerId': 'account.13c6521227184656b64bbe94ce2e5b9c',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 75.12,
#      'vehicleDestroys': 0,
#      'walkDistance': 0,
#      'weaponsAcquired': 0,
#      'winPlace': 29},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '71069593-dfca-4c92-acb3-4af910948092',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 70.417496,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 53,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Ang_Smooddi',
#      'playerId': 'account.4862782bfa8a4ffd844b3ede734cd26c',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 783.12,
#      'vehicleDestroys': 0,
#      'walkDistance': 1474.476,
#      'weaponsAcquired': 7,
#      'winPlace': 5},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'd35ea177-ed95-4f06-a1d3-78576c0665b8',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 1,
#      'damageDealt': 100,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 3,
#      'killPlace': 32,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 5.2256694,
#      'name': 'DouYuTv-3988263',
#      'playerId': 'account.4108c43522b74b4dae6ce9ecfff285db',
#      'revives': 0,
#      'rideDistance': 2542.8577,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 893.581,
#      'vehicleDestroys': 0,
#      'walkDistance': 1526.5011,
#      'weaponsAcquired': 7,
#      'winPlace': 13},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'ad7c93f7-d05a-4e8f-a391-133a7a3171e9',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 184.08395,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 31,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 21.087404,
#      'name': 'HSXH-yan',
#      'playerId': 'account.1c68210a73c744958c08ffc351cf53b1',
#      'revives': 0,
#      'rideDistance': 2487.5781,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 930.432,
#      'vehicleDestroys': 0,
#      'walkDistance': 1302.9209,
#      'weaponsAcquired': 8,
#      'winPlace': 13},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '4f6c04b3-a2bc-4aac-958f-ba694d79845b',
#    'attributes': {'actor': '',
#     'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 3,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 4,
#      'killPlace': 55,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'WN_White',
#      'playerId': 'account.7b80d248c465406386d7c40087ba4a0d',
#      'revives': 1,
#      'rideDistance': 2721.048,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1366.754,
#      'vehicleDestroys': 0,
#      'walkDistance': 1219.1736,
#      'weaponsAcquired': 5,
#      'winPlace': 7}}},
#   {'type': 'participant',
#    'id': 'b888398a-2d46-4e0c-ab27-595b4581e800',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 89,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Vike4z',
#      'playerId': 'account.a5f831ed4a984dd6a6136ceec8725d94',
#      'revives': 1,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 206.183,
#      'vehicleDestroys': 0,
#      'walkDistance': 163.24405,
#      'weaponsAcquired': 2,
#      'winPlace': 27},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'd78d5665-e9f0-47ad-8160-e7c2a444f183',
#    'attributes': {'stats': {'DBNOs': 1,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 86.28798,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 36,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 3.5549645,
#      'name': 'ley1020',
#      'playerId': 'account.73889bf71a6d4019acb5561a480ca25e',
#      'revives': 0,
#      'rideDistance': 1258.4684,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 654.155,
#      'vehicleDestroys': 0,
#      'walkDistance': 1145.645,
#      'weaponsAcquired': 4,
#      'winPlace': 19},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '8ef74080-4dca-4b65-98a9-a35a27b8564b',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 2,
#      'assists': 1,
#      'boosts': 0,
#      'damageDealt': 128.71747,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 1,
#      'killPlace': 39,
#      'killStreaks': 1,
#      'kills': 1,
#      'longestKill': 11.1719475,
#      'name': 'NICE1xu',
#      'playerId': 'account.fa186f47773f43ff8e4e31695d671f7a',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 331.049,
#      'vehicleDestroys': 0,
#      'walkDistance': 507.4775,
#      'weaponsAcquired': 2,
#      'winPlace': 22},
#     'actor': ''}},
#   {'type': 'roster',
#    'id': '5943b47a-5885-4509-83e0-112a993c6c8b',
#    'attributes': {'stats': {'rank': 27, 'teamId': 24},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'participants': {'data': [{'type': 'participant',
#        'id': '93ff38a7-3ca7-42b9-8f0f-19e1adcb3bf4'},
#       {'type': 'participant', 'id': 'b888398a-2d46-4e0c-ab27-595b4581e800'},
#       {'type': 'participant', 'id': '73169f12-6df6-432f-b55b-e4fb57ec2378'}]},
#     'team': {'data': None}}},
#   {'type': 'roster',
#    'id': '6f35355c-3620-4aab-902d-a667b0e74fec',
#    'attributes': {'stats': {'rank': 4, 'teamId': 12},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'd1c3601f-86c3-4bf1-8ac9-58eb4bc91b49'},
#       {'type': 'participant', 'id': 'a7f6ee5c-aba5-4c26-8a85-b6a0d7f73e71'},
#       {'type': 'participant',
#        'id': '88528c1b-c7f7-4b72-91d1-0c20a5325ece'}]}}},
#   {'type': 'participant',
#    'id': '80cc686f-e6b0-4046-8b8f-2d1e492aa032',
#    'attributes': {'shardId': 'steam',
#     'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 4,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 14,
#      'killPlace': 60,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'BBYAGI',
#      'playerId': 'account.756e3517a0844cc586319db0fd62d45d',
#      'revives': 0,
#      'rideDistance': 4715.447,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 990.665,
#      'vehicleDestroys': 0,
#      'walkDistance': 1052.2395,
#      'weaponsAcquired': 6,
#      'winPlace': 11},
#     'actor': ''}},
#   {'type': 'participant',
#    'id': '0adc02cf-f496-405c-8863-b892f39b927c',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 0,
#      'damageDealt': 0,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 0,
#      'killPlace': 77,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Dori1691',
#      'playerId': 'account.216f8b680ba5472a962e16fc7ec3e699',
#      'revives': 0,
#      'rideDistance': 261.5073,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 412.518,
#      'vehicleDestroys': 0,
#      'walkDistance': 692.82263,
#      'weaponsAcquired': 7,
#      'winPlace': 24},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': '4d583f9f-0b73-405e-91cf-3be8cf66efbe',
#    'attributes': {'stats': {'DBNOs': 0,
#      'assists': 0,
#      'boosts': 2,
#      'damageDealt': 62.04,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 2,
#      'killPlace': 74,
#      'killStreaks': 0,
#      'kills': 0,
#      'longestKill': 0,
#      'name': 'Pehnver',
#      'playerId': 'account.2e73331cd502456ab3c835e68df2f3e2',
#      'revives': 0,
#      'rideDistance': 0,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 513.288,
#      'vehicleDestroys': 0,
#      'walkDistance': 893.82477,
#      'weaponsAcquired': 3,
#      'winPlace': 21},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'participant',
#    'id': 'd1c3601f-86c3-4bf1-8ac9-58eb4bc91b49',
#    'attributes': {'stats': {'DBNOs': 5,
#      'assists': 2,
#      'boosts': 9,
#      'damageDealt': 862.2885,
#      'deathType': 'byplayer',
#      'headshotKills': 0,
#      'heals': 11,
#      'killPlace': 4,
#      'killStreaks': 1,
#      'kills': 5,
#      'longestKill': 348.93176,
#      'name': '702by',
#      'playerId': 'account.f250de8f51a449dfbe4ea85ccab1ab7c',
#      'revives': 0,
#      'rideDistance': 1090.5979,
#      'roadKills': 0,
#      'swimDistance': 0,
#      'teamKills': 0,
#      'timeSurvived': 1517.443,
#      'vehicleDestroys': 0,
#      'walkDistance': 2016.5679,
#      'weaponsAcquired': 9,
#      'winPlace': 4},
#     'actor': '',
#     'shardId': 'steam'}},
#   {'type': 'roster',
#    'id': '8db5f7e1-c885-4dc4-8adb-09d809ef602f',
#    'attributes': {'stats': {'rank': 11, 'teamId': 9},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': '80cc686f-e6b0-4046-8b8f-2d1e492aa032'},
#       {'type': 'participant', 'id': '06e3a904-8be5-4465-ae98-20c946e7c022'},
#       {'type': 'participant',
#        'id': '5995a348-b245-4d02-98e8-afe244c70d42'}]}}},
#   {'type': 'roster',
#    'id': 'e60628f5-d367-4865-822c-a6df2e2078e0',
#    'attributes': {'stats': {'rank': 25, 'teamId': 2},
#     'won': 'false',
#     'shardId': 'steam'},
#    'relationships': {'team': {'data': None},
#     'participants': {'data': [{'type': 'participant',
#        'id': 'dcbdff5b-e8c8-48da-b190-ac69167eed1d'},
#       {'type': 'participant', 'id': 'f0808ae4-c201-42c6-b61e-29e5808596c6'},
#       {'type': 'participant', 'id': '325c81fe-bfbb-4200-a398-d15fd6684231'},
#       {'type': 'participant',
#        'id': '52a87de4-6c46-474b-b0ea-8eb89fa41e3a'}]}}}],
#  'links': {'self': 'https://api-origin.playbattlegrounds.com/shards/steam/matches/942beb1d-d704-4a54-ba92-7cbd72e6c1fb'},
#  'meta': {}}

# %%
asset_id = j['data']['relationships']['assets']['data'][0]['id']
for k in j['included'] :
    if k['type'] == 'asset':
        tele_url = k['attributes']['URL']

r2 = requests.get(tele_url)

tele_json = json.loads(r2.text)
tele_json
# Out:
# [{'MatchId': 'match.bro.official.pc-2018-05.steam.squad.krjp.2019.12.28.12.942beb1d-d704-4a54-ba92-7cbd72e6c1fb',
#   'PingQuality': 'low',
#   'SeasonState': 'progress',
#   '_D': '2019-12-28T12:51:28.2468691Z',
#   '_T': 'LogMatchDefinition'},
#  {'accountId': 'account.a19cfeef4caf4fb98fffc11008725a34',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.370Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'IksanAWM',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 240613.796875, 'y': 252676.71875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.a19cfeef4caf4fb98fffc11008725a34',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.399Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'IksanAWM',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 240613.796875, 'y': 252676.71875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.a19cfeef4caf4fb98fffc11008725a34',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.400Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.9f96e1fd6e0c4f37989e3a9c78e22fc3',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.401Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AFTV_Coni',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 216150.5625, 'y': 378034.875, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.9f96e1fd6e0c4f37989e3a9c78e22fc3',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.417Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'AFTV_Coni',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 216150.5625, 'y': 378034.875, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.9f96e1fd6e0c4f37989e3a9c78e22fc3',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.418Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.0f9d15646c694580a724034cd5743010',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.418Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Essenitial_Art',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382456.375, 'y': 434117.53125, 'z': 1338.1083984375},
#    'ranking': 0,
#    'accountId': 'account.0f9d15646c694580a724034cd5743010',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.426Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Essenitial_Art',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382456.375, 'y': 434117.53125, 'z': 1338.1083984375},
#    'ranking': 0,
#    'accountId': 'account.0f9d15646c694580a724034cd5743010',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.426Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ec6995e3299f4c62bb6919b91d9816a6',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.467Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'nikeed',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 382679.5, 'y': 434139.09375, 'z': 1244.4139404296875},
#    'ranking': 0,
#    'accountId': 'account.ec6995e3299f4c62bb6919b91d9816a6',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.484Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'nikeed',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 382679.5, 'y': 434139.09375, 'z': 1244.4139404296875},
#    'ranking': 0,
#    'accountId': 'account.ec6995e3299f4c62bb6919b91d9816a6',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.485Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.a42a7dce0b8a41fb95fe72c9fd816d61',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.487Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': '11111qqqqqq',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 216371.75, 'y': 377793.46875, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.a42a7dce0b8a41fb95fe72c9fd816d61',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.499Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': '11111qqqqqq',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 216371.75, 'y': 377793.46875, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.a42a7dce0b8a41fb95fe72c9fd816d61',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.499Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.cb0e037f9d454d1783c91b91e250e58d',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.537Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'chap-_-',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 382370.5, 'y': 433814.5625, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.cb0e037f9d454d1783c91b91e250e58d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.557Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'chap-_-',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 382370.5, 'y': 433814.5625, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.cb0e037f9d454d1783c91b91e250e58d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.558Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.f250de8f51a449dfbe4ea85ccab1ab7c',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.559Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': '702by',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 382558.0625, 'y': 433748.75, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.f250de8f51a449dfbe4ea85ccab1ab7c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.571Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': '702by',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 382558.0625, 'y': 433748.75, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.f250de8f51a449dfbe4ea85ccab1ab7c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.572Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.f8c7559000ad481db5687ba1de0c082d',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.572Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Dopa3-',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 216474.65625, 'y': 377943.53125, 'z': 1118.71044921875},
#    'ranking': 0,
#    'accountId': 'account.f8c7559000ad481db5687ba1de0c082d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.586Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Dopa3-',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 216474.65625, 'y': 377943.53125, 'z': 1118.71044921875},
#    'ranking': 0,
#    'accountId': 'account.f8c7559000ad481db5687ba1de0c082d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.586Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.5cb617897a25406d8c1f9865b5145865',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.623Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'PUBG_KAF',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 241533.484375, 'y': 252159.796875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.5cb617897a25406d8c1f9865b5145865',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.642Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'PUBG_KAF',
#    'teamId': 8,
#    'health': 100,
#    'location': {'x': 241533.484375, 'y': 252159.796875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.5cb617897a25406d8c1f9865b5145865',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.642Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.d1d25588aacc40a4bdf7979d6f989032',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.656Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AFTV_Blue',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 216228.421875, 'y': 377787.40625, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.d1d25588aacc40a4bdf7979d6f989032',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.669Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'AFTV_Blue',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 216228.421875, 'y': 377787.40625, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.d1d25588aacc40a4bdf7979d6f989032',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.670Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.bf1051adea3d46d78c9412bf49e011ae',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.670Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Hola_Amigo7',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 240203.359375, 'y': 251127.234375, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.bf1051adea3d46d78c9412bf49e011ae',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.681Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Hola_Amigo7',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 240203.359375, 'y': 251127.234375, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.bf1051adea3d46d78c9412bf49e011ae',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.681Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.bd25352ad1624207a29d05e160b7a5a7',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.682Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AFTV_HANNA',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 216566.703125, 'y': 377752.625, 'z': 1118.71044921875},
#    'ranking': 0,
#    'accountId': 'account.bd25352ad1624207a29d05e160b7a5a7',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.695Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'AFTV_HANNA',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 216566.703125, 'y': 377752.625, 'z': 1118.71044921875},
#    'ranking': 0,
#    'accountId': 'account.bd25352ad1624207a29d05e160b7a5a7',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.696Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.1aa8eb8fa2694d35a1b0f573838b0aae',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.697Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'F-Killer97',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 215969.34375, 'y': 377930.25, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.1aa8eb8fa2694d35a1b0f573838b0aae',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.707Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'F-Killer97',
#    'teamId': 10,
#    'health': 100,
#    'location': {'x': 215969.34375, 'y': 377930.25, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.1aa8eb8fa2694d35a1b0f573838b0aae',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.707Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.29673f8b762e46d8bb537d91c46de276',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.708Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AFTV_HingPong',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 216100.9375, 'y': 378539.59375, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.29673f8b762e46d8bb537d91c46de276',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.722Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'AFTV_HingPong',
#    'teamId': 11,
#    'health': 100,
#    'location': {'x': 216100.9375, 'y': 378539.59375, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.29673f8b762e46d8bb537d91c46de276',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.723Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.b2bcd4ce22474ef6aac1f7ba06ecfa0d',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.723Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'tikaisan',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 382126.0625, 'y': 434661.96875, 'z': 1341.03369140625},
#    'ranking': 0,
#    'accountId': 'account.b2bcd4ce22474ef6aac1f7ba06ecfa0d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.734Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'tikaisan',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 382126.0625, 'y': 434661.96875, 'z': 1341.03369140625},
#    'ranking': 0,
#    'accountId': 'account.b2bcd4ce22474ef6aac1f7ba06ecfa0d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.735Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.35ba8313a05546e888aee8a96834624c',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.736Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Tranquillity-R',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 381992.25, 'y': 435361.78125, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.35ba8313a05546e888aee8a96834624c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.749Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Tranquillity-R',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 381992.25, 'y': 435361.78125, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.35ba8313a05546e888aee8a96834624c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.749Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.e3b5281565bd4fc5a9d6c40c6d3c7c0d',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.753Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'wrewerwe',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 216441.953125, 'y': 377632.84375, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.e3b5281565bd4fc5a9d6c40c6d3c7c0d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.769Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'wrewerwe',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 216441.953125, 'y': 377632.84375, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.e3b5281565bd4fc5a9d6c40c6d3c7c0d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.770Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.b9003e3ea0164ed7938a8b5038a33e2e',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.773Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'MOZOO',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 240733.65625, 'y': 251968.625, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.b9003e3ea0164ed7938a8b5038a33e2e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.786Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'MOZOO',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 240733.65625, 'y': 251968.625, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.b9003e3ea0164ed7938a8b5038a33e2e',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.787Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.1c68210a73c744958c08ffc351cf53b1',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.826Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'HSXH-yan',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 382837.1875, 'y': 434530.96875, 'z': 1225.7481689453125},
#    'ranking': 0,
#    'accountId': 'account.1c68210a73c744958c08ffc351cf53b1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.836Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'HSXH-yan',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 382837.1875, 'y': 434530.96875, 'z': 1225.7481689453125},
#    'ranking': 0,
#    'accountId': 'account.1c68210a73c744958c08ffc351cf53b1',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.837Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.14e7690570f941e58a02bb3476d42aa7',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.839Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Windy1219',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382612.1875, 'y': 433923.375, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.14e7690570f941e58a02bb3476d42aa7',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.848Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Windy1219',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382612.1875, 'y': 433923.375, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.14e7690570f941e58a02bb3476d42aa7',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.848Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.2d27ad034c794e4c891a9102c63f83fb',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.867Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Axzv_pnuoc6',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 216819.46875, 'y': 377770.96875, 'z': 1197.8468017578125},
#    'ranking': 0,
#    'accountId': 'account.2d27ad034c794e4c891a9102c63f83fb',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.879Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Axzv_pnuoc6',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 216819.46875, 'y': 377770.96875, 'z': 1197.8468017578125},
#    'ranking': 0,
#    'accountId': 'account.2d27ad034c794e4c891a9102c63f83fb',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.880Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.93ff89726bf246379cb4a1fea7235d49',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.881Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'tubalu127',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 216036.4375, 'y': 377858.09375, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.93ff89726bf246379cb4a1fea7235d49',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.892Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'tubalu127',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 216036.4375, 'y': 377858.09375, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.93ff89726bf246379cb4a1fea7235d49',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.893Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.6e518ad5a6df4c8c89b0850c55255e8d',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.893Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'SSSangKKK',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 239978.140625, 'y': 252270.859375, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.6e518ad5a6df4c8c89b0850c55255e8d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.900Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'SSSangKKK',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 239978.140625, 'y': 252270.859375, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.6e518ad5a6df4c8c89b0850c55255e8d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.900Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.4831737620fa4a8191cfa0e289792ae9',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.901Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Tenki01',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 383055.875, 'y': 435234.15625, 'z': 1225.748046875},
#    'ranking': 0,
#    'accountId': 'account.4831737620fa4a8191cfa0e289792ae9',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.912Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Tenki01',
#    'teamId': 3,
#    'health': 100,
#    'location': {'x': 383055.875, 'y': 435234.15625, 'z': 1225.748046875},
#    'ranking': 0,
#    'accountId': 'account.4831737620fa4a8191cfa0e289792ae9',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.913Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.91183ce4b79b47c7b1de66a95d97e098',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.914Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'lmeixi',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 240612.4375, 'y': 252256.84375, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.91183ce4b79b47c7b1de66a95d97e098',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.925Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'lmeixi',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 240612.4375, 'y': 252256.84375, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.91183ce4b79b47c7b1de66a95d97e098',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.926Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.cc2756f5781a4bf4ae4b93dcc4718f2c',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.926Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'zzommanzaza',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 241107.203125, 'y': 253077, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.cc2756f5781a4bf4ae4b93dcc4718f2c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.935Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'zzommanzaza',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 241107.203125, 'y': 253077, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.cc2756f5781a4bf4ae4b93dcc4718f2c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.935Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.4108c43522b74b4dae6ce9ecfff285db',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.943Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'DouYuTv-3988263',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 381490.9375, 'y': 434306.09375, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.4108c43522b74b4dae6ce9ecfff285db',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.956Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'DouYuTv-3988263',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 381490.9375, 'y': 434306.09375, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.4108c43522b74b4dae6ce9ecfff285db',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:08.957Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.a6848d1f17684b158adaf67fe6504a6d',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.010Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'dunhillgood',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 240588.4375, 'y': 253135.328125, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.a6848d1f17684b158adaf67fe6504a6d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.021Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'dunhillgood',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 240588.4375, 'y': 253135.328125, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.a6848d1f17684b158adaf67fe6504a6d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.022Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.cc00a21375bd4c0695a9d8a27c3f58e2',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.044Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'GIID-DPS',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 240555.390625, 'y': 252981.421875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.cc00a21375bd4c0695a9d8a27c3f58e2',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.053Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'GIID-DPS',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 240555.390625, 'y': 252981.421875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.cc00a21375bd4c0695a9d8a27c3f58e2',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.053Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.756e3517a0844cc586319db0fd62d45d',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.076Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'BBYAGI',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 216174.84375, 'y': 377668.71875, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.756e3517a0844cc586319db0fd62d45d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.084Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'BBYAGI',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 216174.84375, 'y': 377668.71875, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.756e3517a0844cc586319db0fd62d45d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.085Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.59edc36965a84cd8a24b4647d7a38f67',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.086Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Dopa2-',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 216586.0625, 'y': 377591.1875, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.59edc36965a84cd8a24b4647d7a38f67',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.097Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Dopa2-',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 216586.0625, 'y': 377591.1875, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.59edc36965a84cd8a24b4647d7a38f67',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.097Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.6cd071693f78432cb2c970a6490b56ae',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.144Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Lsgo-6',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 382038.9375, 'y': 433880, 'z': 1225.748046875},
#    'ranking': 0,
#    'accountId': 'account.6cd071693f78432cb2c970a6490b56ae',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.156Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Lsgo-6',
#    'teamId': 13,
#    'health': 100,
#    'location': {'x': 382038.9375, 'y': 433880, 'z': 1225.748046875},
#    'ranking': 0,
#    'accountId': 'account.6cd071693f78432cb2c970a6490b56ae',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.157Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.944574d3bb174c4185a8de0a79d07783',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.176Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'qkrwldud_0301',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 241270.71875, 'y': 251800.625, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.944574d3bb174c4185a8de0a79d07783',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.185Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'qkrwldud_0301',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 241270.71875, 'y': 251800.625, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.944574d3bb174c4185a8de0a79d07783',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.185Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.64193adfdb1d45fd888de12e80a3eaf5',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.242Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'MipSsang',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 216056.265625, 'y': 377935.59375, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.64193adfdb1d45fd888de12e80a3eaf5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.253Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'MipSsang',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 216056.265625, 'y': 377935.59375, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.64193adfdb1d45fd888de12e80a3eaf5',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.254Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.fb7ffbf3e96f4e8b9bbdaaa893e80590',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.255Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'YANGZAIFDV',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 215975.9375, 'y': 378133.03125, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.fb7ffbf3e96f4e8b9bbdaaa893e80590',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.264Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'YANGZAIFDV',
#    'teamId': 7,
#    'health': 100,
#    'location': {'x': 215975.9375, 'y': 378133.03125, 'z': 1110.321533203125},
#    'ranking': 0,
#    'accountId': 'account.fb7ffbf3e96f4e8b9bbdaaa893e80590',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.265Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ce9e872c93b848e892d4d512ea6ea036',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.309Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'ckdgud11',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382113.8125, 'y': 434521.875, 'z': 1339.4886474609375},
#    'ranking': 0,
#    'accountId': 'account.ce9e872c93b848e892d4d512ea6ea036',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.319Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'ckdgud11',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382113.8125, 'y': 434521.875, 'z': 1339.4886474609375},
#    'ranking': 0,
#    'accountId': 'account.ce9e872c93b848e892d4d512ea6ea036',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.319Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.1d49fa1779684ba3a81641c79f312253',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.576Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'koonkang',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 239490.59375, 'y': 252287.796875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.1d49fa1779684ba3a81641c79f312253',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.589Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'koonkang',
#    'teamId': 5,
#    'health': 100,
#    'location': {'x': 239490.59375, 'y': 252287.796875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.1d49fa1779684ba3a81641c79f312253',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.590Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.c549afd3dd804d4095a3fe9c8c91b30a',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.676Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'HeungMin-7',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 239558.171875, 'y': 251668.609375, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.c549afd3dd804d4095a3fe9c8c91b30a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.689Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'HeungMin-7',
#    'teamId': 14,
#    'health': 100,
#    'location': {'x': 239558.171875, 'y': 251668.609375, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.c549afd3dd804d4095a3fe9c8c91b30a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:09.690Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.82496f03b52f47718fe6b7ff8fbd6179',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.173Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'SecretShop',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 240304.53125, 'y': 252008.921875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.82496f03b52f47718fe6b7ff8fbd6179',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.179Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'SecretShop',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 240304.53125, 'y': 252008.921875, 'z': 7932.654296875},
#    'ranking': 0,
#    'accountId': 'account.82496f03b52f47718fe6b7ff8fbd6179',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.180Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.ba2bcb7548f348e6ad9ca9149e3bac30',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.673Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Jji--Bam_KYH',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382666.84375, 'y': 434639.8125, 'z': 1353.21240234375},
#    'ranking': 0,
#    'accountId': 'account.ba2bcb7548f348e6ad9ca9149e3bac30',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.684Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Jji--Bam_KYH',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382666.84375, 'y': 434639.8125, 'z': 1353.21240234375},
#    'ranking': 0,
#    'accountId': 'account.ba2bcb7548f348e6ad9ca9149e3bac30',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.684Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.c34e13bc9b914b52a4631f532022fb0a',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.773Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'dlrldnd666',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 216405.953125, 'y': 378528.3125, 'z': 1177.73486328125},
#    'ranking': 0,
#    'accountId': 'account.c34e13bc9b914b52a4631f532022fb0a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.788Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'dlrldnd666',
#    'teamId': 9,
#    'health': 100,
#    'location': {'x': 216405.953125, 'y': 378528.3125, 'z': 1177.73486328125},
#    'ranking': 0,
#    'accountId': 'account.c34e13bc9b914b52a4631f532022fb0a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:10.789Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.3fe6266bcfa94c009201b1bfc0e8667a',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.475Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Boss573',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 216564.59375, 'y': 378209, 'z': 1181.2882080078125},
#    'ranking': 0,
#    'accountId': 'account.3fe6266bcfa94c009201b1bfc0e8667a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.489Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Boss573',
#    'teamId': 4,
#    'health': 100,
#    'location': {'x': 216564.59375, 'y': 378209, 'z': 1181.2882080078125},
#    'ranking': 0,
#    'accountId': 'account.3fe6266bcfa94c009201b1bfc0e8667a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.489Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.229b8299b7344b1494eb534436f54c2a',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.709Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Yuja-__-',
#    'teamId': 18,
#    'health': 100,
#    'location': {'x': 381878.53125, 'y': 434454.21875, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.229b8299b7344b1494eb534436f54c2a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.719Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Yuja-__-',
#    'teamId': 18,
#    'health': 100,
#    'location': {'x': 381878.53125, 'y': 434454.21875, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.229b8299b7344b1494eb534436f54c2a',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.720Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.bbe12e905b5e44dd9357afb71107fd47',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.775Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'Another_Lv_',
#    'teamId': 18,
#    'health': 100,
#    'location': {'x': 382581.90625, 'y': 433672.375, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.bbe12e905b5e44dd9357afb71107fd47',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.786Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Another_Lv_',
#    'teamId': 18,
#    'health': 100,
#    'location': {'x': 382581.90625, 'y': 433672.375, 'z': 1225.74609375},
#    'ranking': 0,
#    'accountId': 'account.bbe12e905b5e44dd9357afb71107fd47',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.786Z',
#   '_T': 'LogPlayerCreate'},
#  {'accountId': 'account.26f635386f85442c9ab80efb8f3be6ef',
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.841Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'K_Search-_-',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 382456.0625, 'y': 434681.09375, 'z': 1353.214599609375},
#    'ranking': 0,
#    'accountId': 'account.26f635386f85442c9ab80efb8f3be6ef',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:50:11.849Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'K_Search-_-',
#    'teamId': 15,
#    'health': 100,
#    'location': {'x': 382456.0625, 'y': 434681.09375, 'z': 1353.214599609375},
#    'ranking': 0,
#    'accountId': 'account.26f635386f85442c9ab80efb8f3be6ef',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'common': {'isGame': 0},
# ...
#   'isLedgeGrab': False,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.599Z',
#   '_T': 'LogVaultStart'},
#  {'attackId': 148,
#   'fireWeaponStackCount': 0,
#   'attacker': {'name': '702by',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 382678.75, 'y': 434058.75, 'z': 1312.75},
#    'ranking': 0,
#    'accountId': 'account.f250de8f51a449dfbe4ea85ccab1ab7c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 1221825327,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.659Z',
#   '_T': 'LogPlayerAttack'},
#  {'attackId': 149,
#   'fireWeaponStackCount': 1,
#   'attacker': {'name': 'Lacle',
#    'teamId': 24,
#    'health': 100,
#    'location': {'x': 216826.46875, 'y': 382805.84375, 'z': 1242.1500244140625},
#    'ranking': 0,
#    'accountId': 'account.0594713fe9f54c279c16cac6821abacf',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.794Z',
#   '_T': 'LogPlayerUseThrowable'},
#  {'attackId': 149,
#   'fireWeaponStackCount': 1,
#   'attacker': {'name': 'Lacle',
#    'teamId': 24,
#    'health': 100,
#    'location': {'x': 216826.46875, 'y': 382805.84375, 'z': 1242.1500244140625},
#    'ranking': 0,
#    'accountId': 'account.0594713fe9f54c279c16cac6821abacf',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.794Z',
#   '_T': 'LogPlayerAttack'},
#  {'character': {'name': 'Lacle',
#    'teamId': 24,
#    'health': 100,
#    'location': {'x': 216826.46875, 'y': 382805.84375, 'z': 1242.1500244140625},
#    'ranking': 0,
#    'accountId': 'account.0594713fe9f54c279c16cac6821abacf',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.794Z',
#   '_T': 'LogItemUnequip'},
#  {'character': {'name': 'Lacle',
#    'teamId': 24,
#    'health': 100,
#    'location': {'x': 216826.46875, 'y': 382805.84375, 'z': 1242.1500244140625},
#    'ranking': 0,
#    'accountId': 'account.0594713fe9f54c279c16cac6821abacf',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.794Z',
#   '_T': 'LogItemEquip'},
#  {'attackId': 151,
#   'fireWeaponStackCount': 161,
#   'attacker': {'name': 'SSSangKKK',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 241330.6875, 'y': 251747.4375, 'z': 7906.7998046875},
#    'ranking': 0,
#    'accountId': 'account.6e518ad5a6df4c8c89b0850c55255e8d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 0,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.799Z',
#   '_T': 'LogPlayerAttack'},
#  {'character': {'name': 'JINTAE__08',
#    'teamId': 20,
#    'health': 100,
#    'location': {'x': 381492.0625, 'y': 437568.34375, 'z': 1214.419921875},
#    'ranking': 0,
#    'accountId': 'account.388dba0df8214d628af5e93e84eafbf3',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'isLedgeGrab': False,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.864Z',
#   '_T': 'LogVaultStart'},
#  {'character': {'name': 'FastAtF',
#    'teamId': 17,
#    'health': 100,
#    'location': {'x': 217730.359375, 'y': 377683.21875, 'z': 1281.719970703125},
#    'ranking': 0,
#    'accountId': 'account.013066f5c82745a49cd587b2731da8e2',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 100,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.973Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'fnzlsla',
#    'teamId': 16,
#    'health': 100,
#    'location': {'x': 239101.59375, 'y': 250344.078125, 'z': 7934.7998046875},
#    'ranking': 0,
#    'accountId': 'account.ea175ac962b74ec488cba72a5d12ab55',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 100,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:02.974Z',
#   '_T': 'LogPlayerPosition'},
#  {'attackId': 152,
#   'fireWeaponStackCount': 160,
#   'attacker': {'name': 'kyu-ta',
#    'teamId': 23,
#    'health': 100,
#    'location': {'x': 382144.75, 'y': 435273.46875, 'z': 1304.43994140625},
#    'ranking': 0,
#    'accountId': 'account.e67d4315d9604a6faea040d237499331',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 0,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.001Z',
#   '_T': 'LogPlayerAttack'},
#  {'attackId': 153,
#   'fireWeaponStackCount': 7,
#   'attacker': {'name': 'lmeixi',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 225971.421875, 'y': 257796.640625, 'z': 8368.109375},
#    'ranking': 0,
#    'accountId': 'account.91183ce4b79b47c7b1de66a95d97e098',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.030Z',
#   '_T': 'LogPlayerUseThrowable'},
#  {'attackId': 153,
#   'fireWeaponStackCount': 7,
#   'attacker': {'name': 'lmeixi',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 225971.421875, 'y': 257796.640625, 'z': 8368.109375},
#    'ranking': 0,
#    'accountId': 'account.91183ce4b79b47c7b1de66a95d97e098',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.030Z',
#   '_T': 'LogPlayerAttack'},
#  {'character': {'name': 'lmeixi',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 225971.421875, 'y': 257796.640625, 'z': 8368.109375},
#    'ranking': 0,
#    'accountId': 'account.91183ce4b79b47c7b1de66a95d97e098',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.030Z',
#   '_T': 'LogItemUnequip'},
#  {'character': {'name': 'lmeixi',
#    'teamId': 6,
#    'health': 100,
#    'location': {'x': 225971.421875, 'y': 257796.640625, 'z': 8368.109375},
#    'ranking': 0,
#    'accountId': 'account.91183ce4b79b47c7b1de66a95d97e098',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.031Z',
#   '_T': 'LogItemEquip'},
#  {'character': {'name': 'Johae',
#    'teamId': 28,
#    'health': 100,
#    'location': {'x': 222231.3125, 'y': 374270.625, 'z': 1202.5899658203125},
#    'ranking': 0,
#    'accountId': 'account.36744d2e42cb455687bddc684d5df69c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'isLedgeGrab': False,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.068Z',
#   '_T': 'LogVaultStart'},
#  {'attackId': 155,
#   'fireWeaponStackCount': 0,
#   'attacker': {'name': 'Vike4z',
#    'teamId': 24,
#    'health': 100,
#    'location': {'x': 216019.3125, 'y': 377863.625, 'z': 1022.969970703125},
#    'ranking': 0,
#    'accountId': 'account.a5f831ed4a984dd6a6136ceec8725d94',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 0,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.097Z',
#   '_T': 'LogPlayerAttack'},
#  {'attackId': 156,
#   'fireWeaponStackCount': 0,
#   'attacker': {'name': '702by',
#    'teamId': 12,
#    'health': 100,
#    'location': {'x': 382668.90625, 'y': 434059.65625, 'z': 1310.010009765625},
#    'ranking': 0,
#    'accountId': 'account.f250de8f51a449dfbe4ea85ccab1ab7c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 0,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.235Z',
#   '_T': 'LogPlayerAttack'},
#  {'attackId': 157,
#   'fireWeaponStackCount': 161,
#   'attacker': {'name': 'SSSangKKK',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 241330.6875, 'y': 251747.4375, 'z': 7906.7998046875},
#    'ranking': 0,
#    'accountId': 'account.6e518ad5a6df4c8c89b0850c55255e8d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 0,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.271Z',
#   '_T': 'LogPlayerAttack'},
#  {'attackId': 158,
#   'fireWeaponStackCount': 12,
#   'attacker': {'name': 'Essenitial_Art',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382955.15625, 'y': 434213.0625, 'z': 1209.429931640625},
#    'ranking': 0,
#    'accountId': 'account.0f9d15646c694580a724034cd5743010',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.332Z',
#   '_T': 'LogPlayerUseThrowable'},
#  {'attackId': 158,
#   'fireWeaponStackCount': 12,
#   'attacker': {'name': 'Essenitial_Art',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382955.15625, 'y': 434213.0625, 'z': 1209.429931640625},
#    'ranking': 0,
#    'accountId': 'account.0f9d15646c694580a724034cd5743010',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.332Z',
#   '_T': 'LogPlayerAttack'},
#  {'character': {'name': 'Essenitial_Art',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382955.15625, 'y': 434213.0625, 'z': 1209.429931640625},
#    'ranking': 0,
#    'accountId': 'account.0f9d15646c694580a724034cd5743010',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.333Z',
#   '_T': 'LogItemUnequip'},
#  {'character': {'name': 'Essenitial_Art',
#    'teamId': 1,
#    'health': 100,
#    'location': {'x': 382955.15625, 'y': 434213.0625, 'z': 1209.429931640625},
#    'ranking': 0,
#    'accountId': 'account.0f9d15646c694580a724034cd5743010',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.333Z',
#   '_T': 'LogItemEquip'},
#  {'attackId': 160,
#   'fireWeaponStackCount': 0,
#   'attacker': {'name': 'Vike4z',
#    'teamId': 24,
#    'health': 100,
#    'location': {'x': 216019.3125, 'y': 377863.625, 'z': 1022.969970703125},
#    'ranking': 0,
#    'accountId': 'account.a5f831ed4a984dd6a6136ceec8725d94',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 0,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.545Z',
#   '_T': 'LogPlayerAttack'},
#  {'attackId': 161,
#   'fireWeaponStackCount': 0,
#   'attacker': {'name': 'gusdlts',
#    'teamId': 27,
#    'health': 100,
#    'location': {'x': 241971.46875, 'y': 251407.78125, 'z': 7934.7998046875},
#    'ranking': 0,
#    'accountId': 'account.22412bd2770740ef9bd73787ae202179',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 0,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.608Z',
#   '_T': 'LogPlayerAttack'},
#  {'attackId': 162,
#   'fireWeaponStackCount': 0,
#   'attacker': {'name': 'SSSangKKK',
#    'teamId': 2,
#    'health': 100,
#    'location': {'x': 241330.6875, 'y': 251747.4375, 'z': 7906.7998046875},
#    'ranking': 0,
#    'accountId': 'account.6e518ad5a6df4c8c89b0850c55255e8d',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': '',
#    'stackCount': 0,
#    'category': '',
#    'subCategory': '',
#    'attachedItems': []},
#   'vehicle': None,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.694Z',
#   '_T': 'LogPlayerAttack'},
#  {'character': {'name': 'Joon-key',
#    'teamId': 22,
#    'health': 100,
#    'location': {'x': 382671.0625, 'y': 436157.1875, 'z': 1262.760009765625},
#    'ranking': 0,
#    'accountId': 'account.7cb6cd5afb034934b44a29ccc3d7ebc9',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 100,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.712Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'ye__ah',
#    'teamId': 22,
#    'health': 100,
#    'location': {'x': 382135.5, 'y': 434282.90625, 'z': 1304.6099853515625},
#    'ranking': 0,
#    'accountId': 'account.941cca89badc4a0e89c528f403d18938',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 100,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.712Z',
#   '_T': 'LogPlayerPosition'},
#  {'character': {'name': 'JINTAE__08',
#    'teamId': 20,
#    'health': 100,
#    'location': {'x': 381457.125, 'y': 437576.78125, 'z': 1285.46484375},
#    'ranking': 0,
#    'accountId': 'account.388dba0df8214d628af5e93e84eafbf3',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'vehicle': None,
#   'elapsedTime': 0,
#   'numAlivePlayers': 100,
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.753Z',
#   '_T': 'LogPlayerPosition'},
#  {'attackId': 163,
#   'fireWeaponStackCount': 7,
#   'attacker': {'name': 'Dori1691',
#    'teamId': 19,
#    'health': 100,
#    'location': {'x': 235134.734375, 'y': 250042.578125, 'z': 8304.609375},
#    'ranking': 0,
#    'accountId': 'account.216f8b680ba5472a962e16fc7ec3e699',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'attackType': 'Weapon',
#   'weapon': {'itemId': 'Item_Weapon_Snowball_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2019-12-28T12:51:03.814Z',
#   '_T': 'LogPlayerUseThrowable'},
#  ...]

# %%
for t in tele_json :
    if t['_T'] == 'LogGameStatePeriodic':
        print(t)
        break
# Out:
# {'gameState': {'elapsedTime': 10, 'numAliveTeams': 29, 'numJoinPlayers': 100, 'numStartPlayers': 100, 'numAlivePlayers': 100, 'safetyZonePosition': {'x': 306050, 'y': 306050, 'z': 0}, 'safetyZoneRadius': 437820.0625, 'poisonGasWarningPosition': {'x': 0, 'y': 0, 'z': 0}, 'poisonGasWarningRadius': 0, 'redZonePosition': {'x': 0, 'y': 0, 'z': 0}, 'redZoneRadius': 0}, 'common': {'isGame': 0.10000000149011612}, '_D': '2019-12-28T12:51:38.829Z', '_T': 'LogGameStatePeriodic'}

# %%
url2 = "https://telemetry-cdn.pubg.com/pc-krjp/2020/01/04/0/0/{}-telemetry.json".format(asset_id)
url2
r = requests.get(url2, headers=header)
r.text
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     363                 )
# --> 364             _match_hostname(cert, self.assert_hostname or server_hostname)
#     365
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connection.py in _match_hostname(cert, asserted_hostname)
#     373     try:
# --> 374         match_hostname(cert, asserted_hostname)
#     375     except CertificateError as e:
#
# C:\ProgramData\Anaconda3\lib\ssl.py in match_hostname(cert, hostname)
#     337             "doesn't match %r"
# --> 338             % (hostname, dnsnames[0]))
#     339     else:
#
# SSLCertVerificationError: ("hostname 'telemetry-cdn.pubg.com' doesn't match '*.playbattlegrounds.com'",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='telemetry-cdn.pubg.com', port=443): Max retries exceeded with url: /pc-krjp/2020/01/04/0/0/52f2e690-2f06-11ea-abb2-16b359ef690a-telemetry.json (Caused by SSLError(SSLCertVerificationError("hostname 'telemetry-cdn.pubg.com' doesn't match '*.playbattlegrounds.com'")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-41-b6d70c26ff27> in <module>
#       1 url2 = "https://telemetry-cdn.pubg.com/pc-krjp/2020/01/04/0/0/{}-telemetry.json".format(asset_id)
#       2 url2
# ----> 3 r = requests.get(url2, headers=header)
#       4 r.text
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='telemetry-cdn.pubg.com', port=443): Max retries exceeded with url: /pc-krjp/2020/01/04/0/0/52f2e690-2f06-11ea-abb2-16b359ef690a-telemetry.json (Caused by SSLError(SSLCertVerificationError("hostname 'telemetry-cdn.pubg.com' doesn't match '*.playbattlegrounds.com'")))

# %%
class LogPlayerPosition(Event):

    def from_dict(self):
        super().from_dict()
        self.character = objects.Character(self._data.get('character', {}))
        self.vehicle = objects.Vehicle(self._data.get('vehicle', {}))
        self.elapsed_time = self._data.get('elapsedTime')
        self.num_alive_players = self._data.get('numAlivePlayers')
        
class LogWeaponFireCount(Event):

    def from_dict(self):
        self.character = objects.Character(self._data.get('character', {}))
        self.weapon_id = self._data.get('weaponId')
        self.fire_count = self._data.get('fireCount')


class LogPlayerAttack(Event):

    def from_dict(self):
        super().from_dict()
        self.attack_id = self._data.get('attackId')
        self.fire_weapon_stack_count = self._data.get('fireWeaponStackCount')
        self.attacker = objects.Character(self._data.get('attacker', {}))
        self.attack_type = self._data.get('attackType')
        self.weapon = objects.Item(self._data.get('weapon', {}))
        self.vehicle = objects.Vehicle(self._data.get('vehicle', {}))


class LogPlayerTakeDamage(Event):

    def from_dict(self):
        super().from_dict()
        self.attack_id = self._data.get('attackId')
        self.attacker = objects.Character(self._data.get('attacker', {}))
        self.victim = objects.Character(self._data.get('victim', {}))
        self.damage_type_category = self._data.get('damageTypeCategory')
        self.damage_reason = self._data.get('damageReason')
        self.damage = self._data.get('damage')
        self.damage_causer_name = self._data.get('damageCauserName')


class LogPlayerKill(Event):

    def from_dict(self):
        super().from_dict()
        self.attack_id = self._data.get('attackId')
        self.killer = objects.Character(self._data.get('killer', {}))
        self.victim = objects.Character(self._data.get('victim', {}))
        self.victim_weapon = self._data.get('victimWeapon')
        self.assistant = objects.Character(self._data.get('assistant', {}))
        self.dbno_id = self._data.get('dBNOId')
        self.damage_type_category = self._data.get('damageTypeCategory')
        self.damage_causer_name = self._data.get('damageCauserName')
        self.damage_causer_additional_info = self._data.get(
            'damageCauserAdditionalInfo', [])
        self.damage_reason = self._data.get('damageReason')
        self.distance = self._data.get('distance')
        self.victim_game_result = objects.GameResult(
            self._data.get('victimGameResult', {}))

class LogPlayerMakeGroggy(Event):

    def from_dict(self):
        super().from_dict()
        self.attack_id = self._data.get('attackId')
        self.attacker = objects.Character(self._data.get('attacker', {}))
        self.victim = objects.Character(self._data.get('victim', {}))
        self.victim_weapon = self._data.get('victimWeapon')
        self.victim_weapon_additional_info = self._data.get(
            'victimWeaponAdditionalInfo')
        self.damage_reason = self._data.get('damageReason')
        self.damage_type_category = self._data.get('damageTypeCategory')
        self.damage_causer_name = self._data.get('damageCauserName')
        self.damage_causer_additional_info = self._data.get(
            'damageCauserAdditionalInfo', [])
        self.distance = self._data.get('distance')
        self.is_attacker_in_vehicle = self._data.get('isAttackerInVehicle')
        self.dbno_id = self._data.get('dBNOId')


class LogPlayerRevive(Event):

    def from_dict(self):
        super().from_dict()
        self.reviver = objects.Character(self._data.get('reviver', {}))
        self.victim = objects.Character(self._data.get('victim', {}))
        self.dbno_id = self._data.get('dBNOId')
        
class LogPlayerUseThrowable(Event):

    def from_dict(self):
        super().from_dict()
        self.attackId = self._data.get('attackId')
        self.fire_weapon_stack_count = self._data.get('fireWeaponStackCount')
        self.attacker = objects.Character(self._data.get('attacker', {}))
        self.attack_type = self._data.get('attackType')
        self.weapon = objects.Item(self._data.get('weapon', {}))
        
# 일단 Item 관련 로그는 수집 전
