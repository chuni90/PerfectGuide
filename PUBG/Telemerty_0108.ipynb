# %% [markdown]
# * Telemetry log
# * 가장 고난이도...어떤 feature를 가져올 지도 고민이 필요함

# %%
import numpy as np
import pandas as pd
import time, datetime

# %%
from pubg_python import PUBG, Shard, Telemetry
my_api = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI2YTQ2YzQwMC0xMmFlLTAxMzgtMzYxMS0yOTc0NWRlZGVmNWQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTc4MzEzOTAxLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImxvdmVyMTQ1Ny1nbWFpIn0.d7TlZC7jMTX_aDhV8NcMiPgzAwFCW5x-gWe1ISMwgtg'
api = PUBG(my_api, Shard.PC_KRJP)

# %%
match_id = 'b38b3cc1-7c9a-42c4-8538-3718c8477c5d'
match_obj = api.matches().get(match_id)
match_obj.created_at
# Out:
# '2020-01-06T15:13:05Z'

# %%
# match_obj에 안에 있는 assets.url이 telemerty.json이 저장되어 있음
asset = match_obj.assets[0]
asset.url
# Out:
# 'https://telemetry-cdn.playbattlegrounds.com/bluehole-pubg/steam/2020/01/06/15/40/dab8ae33-309a-11ea-94eb-72bf6dbe5d63-telemetry.json'

# %% [markdown]
# https://telemetry-cdn.playbattlegrounds.com/bluehole-pubg/steam/2019/12/28/13/22/21a76517-2975-11ea-b19c-c2f203cc5701-telemetry.json

# %%
# telemetry & telemetry.events load
telemetry = api.telemetry(asset.url)
events = telemetry.events
len(events)
# 1개 match에 events log가 23,853개..
# 특정 매치는 4만개가 넘기도 했음. 그래서 시간이 매우 오래 걸림
# Out:
# 23853

# %%
# 모든 event log를 보려고 했더니, Attribute error 발생
# 'LogPlayerLogout' object has no attribute 'event'

num = 0
for event in events :
    num += 1
    print(num, ":", event.event)
# Out:
# 1 : LogMatchDefinition
# 2 : LogPlayerLogin
# 3 : LogItemEquip
# 4 : LogPlayerCreate
# 5 : LogPlayerLogin
# 6 : LogItemEquip
# 7 : LogPlayerCreate
# 8 : LogPlayerLogin
# 9 : LogItemEquip
# 10 : LogPlayerCreate
# 11 : LogPlayerLogin
# 12 : LogItemEquip
# 13 : LogPlayerCreate
# 14 : LogPlayerLogin
# 15 : LogItemEquip
# 16 : LogPlayerCreate
# 17 : LogPlayerLogin
# 18 : LogItemEquip
# 19 : LogPlayerCreate
# 20 : LogPlayerLogin
# 21 : LogItemEquip
# 22 : LogPlayerCreate
# 23 : LogPlayerLogin
# 24 : LogItemEquip
# 25 : LogPlayerCreate
# 26 : LogPlayerLogin
# 27 : LogItemEquip
# 28 : LogPlayerCreate
# 29 : LogPlayerLogin
# 30 : LogItemEquip
# 31 : LogPlayerCreate
# 32 : LogPlayerLogin
# 33 : LogItemEquip
# 34 : LogPlayerCreate
# 35 : LogPlayerLogin
# 36 : LogItemEquip
# 37 : LogPlayerCreate
# 38 : LogPlayerLogin
# 39 : LogItemEquip
# 40 : LogPlayerCreate
# 41 : LogPlayerLogin
# 42 : LogItemEquip
# 43 : LogPlayerCreate
# 44 : LogPlayerLogin
# 45 : LogItemEquip
# 46 : LogPlayerCreate
# ...

# %%
events_list = []
for event in events:
    events_list.append(str(event).split('.')[4].split(' ')[0])
    
e_df = pd.DataFrame(events_list,columns=['logname'])
print(e_df.shape)
e_df.head()
# Out:
# (23853, 1)
#               logname
# 0  LogMatchDefinition
# 1      LogPlayerLogin
# 2        LogItemEquip
# 3     LogPlayerCreate
# 4      LogPlayerLogin

# %%
e_df['logname'].value_counts()
# Out:
# LogPlayerPosition               5606
# LogItemPickup                   3232
# LogPlayerAttack                 2683
# LogPlayerTakeDamage             2461
# LogHeal                         1964
# LogItemEquip                    1165
# LogItemUnequip                  1158
# LogObjectInteraction             839
# LogItemDrop                      739
# LogVaultStart                    729
# LogItemAttach                    688
# LogItemDetach                    672
# LogItemPickupFromLootBox         369
# LogWeaponFireCount               209
# LogItemUse                       199
# LogPlayerUseThrowable            182
# LogGameStatePeriodic             152
# LogVehicleRide                   116
# LogVehicleLeave                  116
# LogPlayerLogin                    99
# LogPlayerCreate                   98
# LogPlayerLogout                   98
# LogParachuteLanding               95
# LogPlayerKill                     94
# LogItemPickupFromCarepackage      21
# ...

# %%
e_df['logname'].unique()
# Out:
# array(['LogMatchDefinition', 'LogPlayerLogin', 'LogItemEquip',
#        'LogPlayerCreate', 'LogPlayerPosition', 'LogPlayerUseThrowable',
#        'LogPlayerAttack', 'LogItemUnequip', 'LogVaultStart',
#        'LogObjectInteraction', 'LogPlayerLogout', 'LogWeaponFireCount',
#        'LogSwimStart', 'LogVehicleRide', 'LogItemPickup', 'LogMatchStart',
#        'LogGameStatePeriodic', 'LogVehicleLeave', 'LogParachuteLanding',
#        'LogItemAttach', 'LogPlayerTakeDamage', 'LogPlayerKill',
#        'LogItemDrop', 'LogItemPickupFromLootBox', 'LogItemDetach',
#        'LogItemUse', 'LogHeal', 'LogArmorDestroy', 'LogPhaseChange',
#        'LogObjectDestroy', 'LogSwimEnd', 'LogCarePackageSpawn',
#        'LogCarePackageLand', 'LogItemPickupFromCarepackage',
#        'LogWheelDestroy', 'LogVehicleDestroy', 'LogMatchEnd'],
#       dtype=object)

# %%
# LogSwimStart
for imp in range(15):
    swim = telemetry.events_from_type('LogSwimStart')[imp]
    print(swim.timestamp)
# Out:
# 2020-01-06T15:12:37.443Z
# 2020-01-06T15:12:39.081Z
# 2020-01-06T15:12:45.786Z
# 2020-01-06T15:12:47.515Z
# 2020-01-06T15:12:54.730Z
# 2020-01-06T15:15:09.588Z
# 2020-01-06T15:16:21.331Z
# 2020-01-06T15:16:39.829Z
# 2020-01-06T15:21:16.824Z
# 2020-01-06T15:21:38.277Z
# 2020-01-06T15:22:19.513Z
# 2020-01-06T15:22:53.378Z
# 2020-01-06T15:23:04.261Z
# 2020-01-06T15:23:39.175Z
# 2020-01-06T15:24:09.136Z

# %%
# LogSwimEnd
for imp in range(10):
    swim = telemetry.events_from_type('LogSwimEnd')[imp]
    print(swim.event, swim.timestamp)
    print(swim.swim_distance)
    print(swim)
# Out:
# LogSwimEnd 2020-01-06T15:15:38.538Z
# 1.8024542331695557
# ...
# LogSwimEnd 2020-01-06T15:16:22.989Z
# 4.232536792755127
# ...
# LogSwimEnd 2020-01-06T15:16:44.671Z
# 17.16118621826172
# ...
# LogSwimEnd 2020-01-06T15:21:18.532Z
# 4.706547260284424
# ...
# LogSwimEnd 2020-01-06T15:21:44.310Z
# 19.41337776184082
# ...
# LogSwimEnd 2020-01-06T15:22:53.212Z
# 94.71559143066406
# ...
# LogSwimEnd 2020-01-06T15:23:04.060Z
# 20.569503784179688
# ...
# LogSwimEnd 2020-01-06T15:23:37.307Z
# 36.67742156982422
# ...
# LogSwimEnd 2020-01-06T15:23:45.986Z
# 19.184463500976562
# ...
# LogSwimEnd 2020-01-06T15:24:25.287Z
# 18.964603424072266
# ...

# %% [markdown]
# ### 여기서 문제 발생
# * wrapper에선 모든 telemetry log를 가져올 수 없음(특정 로그만 가능함)
# * 그래서 requests를 이용한 방식도 일단 구현은 해놓은 상태

# %%
import requests, json

my_api = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJqdGkiOiI2YTQ2YzQwMC0xMmFlLTAxMzgtMzYxMS0yOTc0NWRlZGVmNWQiLCJpc3MiOiJnYW1lbG9ja2VyIiwiaWF0IjoxNTc4MzEzOTAxLCJwdWIiOiJibHVlaG9sZSIsInRpdGxlIjoicHViZyIsImFwcCI6ImxvdmVyMTQ1Ny1nbWFpIn0.d7TlZC7jMTX_aDhV8NcMiPgzAwFCW5x-gWe1ISMwgtg'
url = 'https://api.pubg.com/shards/steam/matches/{}'.format(match_id)

header = {
  "Authorization": "Bearer <"+ my_api + ">",
  "Accept": "application/vnd.api+json"
}

r = requests.get(url, headers=header)

# %%
print(r.text)
# Out:
# {"data":{"type":"match","id":"b38b3cc1-7c9a-42c4-8538-3718c8477c5d","attributes":{"duration":1523,"stats":null,"gameMode":"solo","shardId":"steam","tags":null,"isCustomMatch":false,"createdAt":"2020-01-06T15:13:05Z","titleId":"bluehole-pubg","mapName":"Savage_Main","seasonState":"progress"},"relationships":{"rosters":{"data":[{"type":"roster","id":"f56bbeca-e9b5-497d-ad90-f7c78ac8a9ad"},{"type":"roster","id":"a28136b0-ee27-455a-9a9e-e9eff185e304"},{"type":"roster","id":"1ff85954-786d-4778-8526-b563f6f6d550"},{"type":"roster","id":"c3b1eb63-b60f-422b-93a2-abcebf97188c"},{"type":"roster","id":"b282d9ae-ee7b-4b4d-afb8-7033f7f103ab"},{"type":"roster","id":"5d246c13-c823-40a8-8cf2-35c59dd32521"},{"type":"roster","id":"a6c5f222-35e8-4a1d-a8f9-4d422dfb7f71"},{"type":"roster","id":"1622df88-16e4-4fe5-a484-21d89a2ce23c"},{"type":"roster","id":"1919570e-3270-4c26-91d8-df0344548a40"},{"type":"roster","id":"d7920bd5-e9b6-4c15-8267-1787f3346a39"},{"type":"roster","id":"a9809d48-6a6e-40e6-a021-f79
# ...

# %%
# 보기 쉽게 json형식으로 변환
j = json.loads(r.text)
j
# Out:
# {'data': {'type': 'match',
#   'id': 'b38b3cc1-7c9a-42c4-8538-3718c8477c5d',
#   'attributes': {'duration': 1523,
#    'stats': None,
#    'gameMode': 'solo',
#    'shardId': 'steam',
#    'tags': None,
#    'isCustomMatch': False,
#    'createdAt': '2020-01-06T15:13:05Z',
#    'titleId': 'bluehole-pubg',
#    'mapName': 'Savage_Main',
#    'seasonState': 'progress'},
#   'relationships': {'rosters': {'data': [{'type': 'roster',
#       'id': 'f56bbeca-e9b5-497d-ad90-f7c78ac8a9ad'},
#      {'type': 'roster', 'id': 'a28136b0-ee27-455a-9a9e-e9eff185e304'},
#      {'type': 'roster', 'id': '1ff85954-786d-4778-8526-b563f6f6d550'},
#      {'type': 'roster', 'id': 'c3b1eb63-b60f-422b-93a2-abcebf97188c'},
#      {'type': 'roster', 'id': 'b282d9ae-ee7b-4b4d-afb8-7033f7f103ab'},
#      {'type': 'roster', 'id': '5d246c13-c823-40a8-8cf2-35c59dd32521'},
#      {'type': 'roster', 'id': 'a6c5f222-35e8-4a1d-a8f9-4d422dfb7f71'},
# ...

# %%
asset_id = j['data']['relationships']['assets']['data'][0]['id']
for k in j['included'] :
    if k['type'] == 'asset':
        tele_url = k['attributes']['URL']

r2 = requests.get(tele_url)

tele_json = json.loads(r2.text)
tele_json
# Out:
# [{'MatchId': 'match.bro.official.pc-2018-05.steam.solo.krjp.2020.01.06.15.b38b3cc1-7c9a-42c4-8538-3718c8477c5d',
#   'PingQuality': 'low',
#   'SeasonState': 'progress',
#   '_D': '2020-01-06T15:13:05.4683814Z',
#   '_T': 'LogMatchDefinition'},
#  {'accountId': 'account.754555fe15184c36a43e348e0287566c',
#   'common': {'isGame': 0},
#   '_D': '2020-01-06T15:11:29.025Z',
#   '_T': 'LogPlayerLogin'},
#  {'character': {'name': 'AFTV_co-co',
#    'teamId': 100000,
#    'health': 100,
#    'location': {'x': 123055.5234375, 'y': 337369.34375, 'z': 1108.126953125},
#    'ranking': 0,
#    'accountId': 'account.754555fe15184c36a43e348e0287566c',
#    'isInBlueZone': False,
#    'isInRedZone': False,
#    'zone': []},
#   'item': {'itemId': 'Item_Weapon_Apple_C',
#    'stackCount': 1,
#    'category': 'Equipment',
#    'subCategory': 'Throwable',
#    'attachedItems': []},
#   'common': {'isGame': 0},
#   '_D': '2020-01-06T15:11:29.036Z',
#   '_T': 'LogItemEquip'},
# ...

# %%
for t in tele_json :
    if t['_T'] == 'LogMatchStart':
        print(t['_D'], "type:", pd.to_datetime(t['_D']))
        start = pd.to_datetime(t['_D'])
# Out:
# 2020-01-06T15:13:05.453Z type: 2020-01-06 15:13:05.453000+00:00

# %%
for t in tele_json :
    if ( pd.to_datetime(t['_D']) > start ) and (t['_T'] == 'LogSwimStart'):
        if t['character']['name'] == 'ZanD-_-b':
            print("name:", t['character']['name'])
            print("location:", t['character']['location'])
            print("accountId:", t['character']['accountId'])
            print("time:", t['_D'])
            print()
# Out:
# name: ZanD-_-b
# location: {'x': 166656.390625, 'y': 185614.21875, 'z': -67.45175170898438}
# accountId: account.4700e8623c824bd7884694573c3f173e
# time: 2020-01-06T15:22:19.513Z
#
# name: ZanD-_-b
# location: {'x': 172256.578125, 'y': 189815.4375, 'z': -56.9638786315918}
# accountId: account.4700e8623c824bd7884694573c3f173e
# time: 2020-01-06T15:22:53.378Z
#
# name: ZanD-_-b
# location: {'x': 172250.15625, 'y': 189814.578125, 'z': -55.97768020629883}
# accountId: account.4700e8623c824bd7884694573c3f173e
# time: 2020-01-06T15:23:04.261Z
#
# name: ZanD-_-b
# location: {'x': 173743.109375, 'y': 188113.34375, 'z': -59.827667236328125}
# accountId: account.4700e8623c824bd7884694573c3f173e
# time: 2020-01-06T15:23:39.175Z

# %%
for t in tele_json :
    if t['_T'] == 'LogSwimEnd':
        if t['character']['name'] == 'ZanD-_-b':
            print("name:", t['character']['name'])
            print("location:", t['character']['location'])
            print("accountId:", t['character']['accountId'])
            print("time:", t['_D'])
            print()
# Out:
# name: ZanD-_-b
# location: {'x': 172249.515625, 'y': 189809.21875, 'z': -40.94118881225586}
# accountId: account.4700e8623c824bd7884694573c3f173e
# time: 2020-01-06T15:22:53.212Z
#
# name: ZanD-_-b
# location: {'x': 172244.9375, 'y': 189807.484375, 'z': -36.76383972167969}
# accountId: account.4700e8623c824bd7884694573c3f173e
# time: 2020-01-06T15:23:04.060Z
#
# name: ZanD-_-b
# location: {'x': 173801.703125, 'y': 188197.640625, 'z': -27.88836669921875}
# accountId: account.4700e8623c824bd7884694573c3f173e
# time: 2020-01-06T15:23:37.307Z
#
# name: ZanD-_-b
# location: {'x': 174616.171875, 'y': 186658.171875, 'z': -64.27999877929688}
# accountId: account.4700e8623c824bd7884694573c3f173e
# time: 2020-01-06T15:23:45.986Z

# %% [markdown]
# #### 날씨 얻어오기
# * 추후 wrapper 클래스로 작성된 match_df 날씨 호출 코드를 이걸로 대체하는 게 실행 속도 향상에 도움이 될 듯

# %%
for t in tele_json :
    if t['_T'] == 'LogMatchStart':
        print(t['weatherId'])
# Out:
# Clear
